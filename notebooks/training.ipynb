# %%
import warnings
warnings.filterwarnings('ignore')
import os
import re
import json
import string
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from transformers import AutoTokenizer, TFAutoModel
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from modules.dataframe_tools import *
from modules.utils import *
from modules.BERTmodels import *

# %% [markdown]
# # Initializing
# In this section we initialize the dataset. The dataset split happens based on titles.
#
# The Dataset is stored as Json.
# The overallo process consists in:
# - json
# - DataFrame
# - Cleaning
# - Tokenization
# - Creation Input_Mask and Input_Ids
# - Embedding through a BERT model
# - Training the new model

# %%
max_len = 512

# Save the slow pretrained tokenizer
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)

path = '/content/drive/MyDrive/NLP/proj finale/dataset/training_set.json'
error_path = "/content/drive/MyDrive/NLP/proj finale/utils/errors.txt"
error_ids = get_errors(error_path)
test_set_dim = 2
df_orig = create_df_train(path, error_ids, parag_drop=test_set_dim)
# df_test = create_df_test(path, error_ids, parag_lift=test_set_dim)
df = process_dataset(df_orig, tokenizer, answer_available=True, max_len=max_len)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (720 > 512). Running this sequence through the model will result in indexing errors

# %%
x_train,y_train, x_val, y_val = train_val_split_on_title(df)

# %% [markdown]
# ## BERT Ensemble Model
# > The full explanation of the BERT Ensemble model is available on the attached report.
#
# The ensemble model is composed by different neural networks. The following section shows the training of those networks with the same dataframe.

# %% [markdown]
# In the cell below we prepare:
#  * The inputs for the neural netorks
#  * TPU platform to accelerate the training
#  * The accuracy function, loss, and optimizer
#  * The callbacks for Earlystops and checkpoints

# %%
# Create input layer for the neural networks
input_ids = layers.Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
token_type_ids = layers.Input(shape=(max_len,), dtype=tf.int32, name="token_type_ids")
attention_mask = layers.Input(shape=(max_len,), dtype=tf.int32, name="attention_mask")

inputs = [input_ids, token_type_ids, attention_mask]

# %%
save_path= '/content/drive/MyDrive/NLP/proj finale/saved_models/'

# %%
# Create distribution strategy
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
strategy = tf.distribute.TPUStrategy(tpu)

ES_start = EarlyStopping(monitor='val_start_pred_average_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)
ES_end = EarlyStopping(monitor='val_end_pred_average_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)

# Save the slow pretrained tokenizer
path = '/content/drive/MyDrive/NLP/proj finale/dataset'

loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = keras.optimizers.Adam(lr=1e-5, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
# Out:
# INFO:absl:Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0

# %%
def accuracy(y_true, y_pred):
    sampled = tf.argmax(y_pred, axis=-1)
    if len(sampled)==0:
        return np.float64(1)   
    acc = 1 - tf.math.count_nonzero(tf.squeeze(tf.cast(y_true, tf.int64)) - sampled) / tf.cast(len(sampled), tf.int64)
    return acc

# %% [markdown]
# # Average

# %%
layer_option = "average"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'

# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_custom(model_name, custom_layer = layer_option, inputs=inputs)

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]

loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = keras.optimizers.Adam(lr=1e-5, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
model.compile(optimizer=optimizer, loss=[loss, loss], metrics=["accuracy"])

model.summary()
# Out:
# DEBUG:filelock:Attempting to acquire lock 140530324629392 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140530324629392 acquired on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140530324629392 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140530324629392 released on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_average (Dense)     (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_average (Dense)       (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_average[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_average[0][0]
# __________________________________________________________________________________________________
# flatten_start_average (Flatten) (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_average (Flatten)   (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 512)          0           flatten_start_average[0][0]
#                                                                  flatten_int_average[0][0]
# __________________________________________________________________________________________________
# start_pred_average (Activation) (None, 512)          0           flatten_start_average[0][0]
# __________________________________________________________________________________________________
# end_pred_average (Activation)   (None, 512)          0           average[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=25,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/25
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 8.1052 - start_pred_average_loss: 4.3466 - end_pred_average_loss: 3.7587 - start_pred_average_accuracy: 0.2553 - end_pred_average_accuracy: 0.2706
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 435s 667ms/step - loss: 8.1052 - start_pred_average_loss: 4.3466 - end_pred_average_loss: 3.7587 - start_pred_average_accuracy: 0.2553 - end_pred_average_accuracy: 0.2706 - val_loss: 3.8171 - val_start_pred_average_loss: 2.1068 - val_end_pred_average_loss: 1.7102 - val_start_pred_average_accuracy: 0.5667 - val_end_pred_average_accuracy: 0.6090
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 2/25
# 507/507 [==============================] - 260s 512ms/step - loss: 6.8207 - start_pred_average_loss: 3.8030 - end_pred_average_loss: 3.0177 - start_pred_average_accuracy: 0.3496 - end_pred_average_accuracy: 0.4197 - val_loss: 3.1597 - val_start_pred_average_loss: 1.7503 - val_end_pred_average_loss: 1.4095 - val_start_pred_average_accuracy: 0.6090 - val_end_pred_average_accuracy: 0.6540
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 3/25
# 507/507 [==============================] - 260s 513ms/step - loss: 6.5140 - start_pred_average_loss: 3.6708 - end_pred_average_loss: 2.8431 - start_pred_average_accuracy: 0.3730 - end_pred_average_accuracy: 0.4575 - val_loss: 2.9061 - val_start_pred_average_loss: 1.6304 - val_end_pred_average_loss: 1.2757 - val_start_pred_average_accuracy: 0.6248 - val_end_pred_average_accuracy: 0.6743
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 4/25
# 507/507 [==============================] - 261s 515ms/step - loss: 6.3110 - start_pred_average_loss: 3.5965 - end_pred_average_loss: 2.7145 - start_pred_average_accuracy: 0.3862 - end_pred_average_accuracy: 0.4844 - val_loss: 2.7516 - val_start_pred_average_loss: 1.5390 - val_end_pred_average_loss: 1.2126 - val_start_pred_average_accuracy: 0.6406 - val_end_pred_average_accuracy: 0.6859
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 5/25
# 507/507 [==============================] - 261s 515ms/step - loss: 6.2087 - start_pred_average_loss: 3.5541 - end_pred_average_loss: 2.6546 - start_pred_average_accuracy: 0.3954 - end_pred_average_accuracy: 0.4973 - val_loss: 2.6892 - val_start_pred_average_loss: 1.5090 - val_end_pred_average_loss: 1.1802 - val_start_pred_average_accuracy: 0.6428 - val_end_pred_average_accuracy: 0.6904
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 6/25
# 507/507 [==============================] - 261s 514ms/step - loss: 6.1085 - start_pred_average_loss: 3.5295 - end_pred_average_loss: 2.5790 - start_pred_average_accuracy: 0.3985 - end_pred_average_accuracy: 0.5145 - val_loss: 2.5980 - val_start_pred_average_loss: 1.4444 - val_end_pred_average_loss: 1.1536 - val_start_pred_average_accuracy: 0.6512 - val_end_pred_average_accuracy: 0.6963
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 7/25
# 507/507 [==============================] - 261s 514ms/step - loss: 6.0038 - start_pred_average_loss: 3.4802 - end_pred_average_loss: 2.5236 - start_pred_average_accuracy: 0.4060 - end_pred_average_accuracy: 0.5258 - val_loss: 2.5578 - val_start_pred_average_loss: 1.4086 - val_end_pred_average_loss: 1.1492 - val_start_pred_average_accuracy: 0.6502 - val_end_pred_average_accuracy: 0.6966
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 8/25
# 507/507 [==============================] - 261s 514ms/step - loss: 5.8835 - start_pred_average_loss: 3.4363 - end_pred_average_loss: 2.4472 - start_pred_average_accuracy: 0.4148 - end_pred_average_accuracy: 0.5418 - val_loss: 2.5481 - val_start_pred_average_loss: 1.4026 - val_end_pred_average_loss: 1.1455 - val_start_pred_average_accuracy: 0.6536 - val_end_pred_average_accuracy: 0.6961
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 9/25
# 507/507 [==============================] - 261s 514ms/step - loss: 5.8061 - start_pred_average_loss: 3.4013 - end_pred_average_loss: 2.4048 - start_pred_average_accuracy: 0.4215 - end_pred_average_accuracy: 0.5513 - val_loss: 2.5529 - val_start_pred_average_loss: 1.4024 - val_end_pred_average_loss: 1.1505 - val_start_pred_average_accuracy: 0.6561 - val_end_pred_average_accuracy: 0.6999
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 10/25
# 507/507 [==============================] - 261s 514ms/step - loss: 5.7138 - start_pred_average_loss: 3.3667 - end_pred_average_loss: 2.3472 - start_pred_average_accuracy: 0.4268 - end_pred_average_accuracy: 0.5604 - val_loss: 2.5735 - val_start_pred_average_loss: 1.4189 - val_end_pred_average_loss: 1.1545 - val_start_pred_average_accuracy: 0.6540 - val_end_pred_average_accuracy: 0.6979
#
# Epoch 00010: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 11/25
# 507/507 [==============================] - 260s 513ms/step - loss: 5.6671 - start_pred_average_loss: 3.3657 - end_pred_average_loss: 2.3014 - start_pred_average_accuracy: 0.4265 - end_pred_average_accuracy: 0.5695 - val_loss: 2.5526 - val_start_pred_average_loss: 1.3913 - val_end_pred_average_loss: 1.1613 - val_start_pred_average_accuracy: 0.6564 - val_end_pred_average_accuracy: 0.6990
#
# Epoch 00011: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 12/25
# 507/507 [==============================] - 260s 513ms/step - loss: 5.5946 - start_pred_average_loss: 3.3231 - end_pred_average_loss: 2.2715 - start_pred_average_accuracy: 0.4330 - end_pred_average_accuracy: 0.5784 - val_loss: 2.5894 - val_start_pred_average_loss: 1.3901 - val_end_pred_average_loss: 1.1992 - val_start_pred_average_accuracy: 0.6561 - val_end_pred_average_accuracy: 0.6992
#
# Epoch 00012: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 13/25
# 507/507 [==============================] - 261s 515ms/step - loss: 5.5153 - start_pred_average_loss: 3.2955 - end_pred_average_loss: 2.2198 - start_pred_average_accuracy: 0.4390 - end_pred_average_accuracy: 0.5877 - val_loss: 2.6419 - val_start_pred_average_loss: 1.4035 - val_end_pred_average_loss: 1.2384 - val_start_pred_average_accuracy: 0.6542 - val_end_pred_average_accuracy: 0.6967
# Restoring model weights from the end of the best epoch.
#
# Epoch 00013: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_average.hdf5
# Epoch 00013: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'start_pred_average_loss', 'end_pred_average_loss', 'start_pred_average_accuracy', 'end_pred_average_accuracy', 'val_loss', 'val_start_pred_average_loss', 'val_end_pred_average_loss', 'val_start_pred_average_accuracy', 'val_end_pred_average_accuracy'])

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["end_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_end_pred_" + layer_option + "_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_accuracy", "end_pred_" + layer_option + "_accuracy", "val_start_pred_" + layer_option + "_accuracy", "val_end_pred_" + layer_option + "_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history["start_pred_" + layer_option + "_loss"])
plt.plot(history.history["end_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_start_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_end_pred_" + layer_option + "_loss"])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_loss", "end_pred_" + layer_option + "_loss", "val_start_pred_" + layer_option + "_loss", "val_end_pred_" + layer_option + "_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # Maximum

# %%
layer_option = "maximum"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'

# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_custom(model_name, custom_layer = layer_option, inputs=inputs)

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]

loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = keras.optimizers.Adam(lr=1e-5, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
model.compile(optimizer=optimizer, loss=[loss, loss], metrics=["accuracy"])

model.summary()
# Out:
# DEBUG:filelock:Attempting to acquire lock 140229423822032 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140229423822032 acquired on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140229423822032 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140229423822032 released on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_maximum (Dense)     (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_maximum (Dense)       (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_maximum[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_maximum[0][0]
# __________________________________________________________________________________________________
# flatten_start_maximum (Flatten) (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_maximum (Flatten)   (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# maximum (Maximum)               (None, 512)          0           flatten_start_maximum[0][0]
#                                                                  flatten_int_maximum[0][0]
# __________________________________________________________________________________________________
# start_pred_maximum (Activation) (None, 512)          0           flatten_start_maximum[0][0]
# __________________________________________________________________________________________________
# end_pred_maximum (Activation)   (None, 512)          0           maximum[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=25,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/25
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 8.1051 - start_pred_maximum_loss: 4.4251 - end_pred_maximum_loss: 3.6800 - start_pred_maximum_accuracy: 0.2309 - end_pred_maximum_accuracy: 0.3262
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 416s 656ms/step - loss: 8.1051 - start_pred_maximum_loss: 4.4251 - end_pred_maximum_loss: 3.6800 - start_pred_maximum_accuracy: 0.2309 - end_pred_maximum_accuracy: 0.3262 - val_loss: 4.4483 - val_start_pred_maximum_loss: 2.4054 - val_end_pred_maximum_loss: 2.0429 - val_start_pred_maximum_accuracy: 0.5100 - val_end_pred_maximum_accuracy: 0.6172
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 2/25
# 507/507 [==============================] - 257s 506ms/step - loss: 6.9063 - start_pred_maximum_loss: 3.9321 - end_pred_maximum_loss: 2.9743 - start_pred_maximum_accuracy: 0.3141 - end_pred_maximum_accuracy: 0.4553 - val_loss: 3.8043 - val_start_pred_maximum_loss: 1.9991 - val_end_pred_maximum_loss: 1.8052 - val_start_pred_maximum_accuracy: 0.5658 - val_end_pred_maximum_accuracy: 0.6545
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 3/25
# 507/507 [==============================] - 257s 506ms/step - loss: 6.6172 - start_pred_maximum_loss: 3.7940 - end_pred_maximum_loss: 2.8232 - start_pred_maximum_accuracy: 0.3403 - end_pred_maximum_accuracy: 0.4824 - val_loss: 3.6337 - val_start_pred_maximum_loss: 1.9402 - val_end_pred_maximum_loss: 1.6935 - val_start_pred_maximum_accuracy: 0.5712 - val_end_pred_maximum_accuracy: 0.6710
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 4/25
# 507/507 [==============================] - 257s 507ms/step - loss: 6.4355 - start_pred_maximum_loss: 3.7178 - end_pred_maximum_loss: 2.7177 - start_pred_maximum_accuracy: 0.3564 - end_pred_maximum_accuracy: 0.5048 - val_loss: 3.4944 - val_start_pred_maximum_loss: 1.8459 - val_end_pred_maximum_loss: 1.6485 - val_start_pred_maximum_accuracy: 0.6037 - val_end_pred_maximum_accuracy: 0.6791
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 5/25
# 507/507 [==============================] - 257s 507ms/step - loss: 6.2804 - start_pred_maximum_loss: 3.6628 - end_pred_maximum_loss: 2.6176 - start_pred_maximum_accuracy: 0.3666 - end_pred_maximum_accuracy: 0.5199 - val_loss: 3.2312 - val_start_pred_maximum_loss: 1.7331 - val_end_pred_maximum_loss: 1.4982 - val_start_pred_maximum_accuracy: 0.5888 - val_end_pred_maximum_accuracy: 0.6874
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 6/25
# 507/507 [==============================] - 257s 507ms/step - loss: 6.2045 - start_pred_maximum_loss: 3.6486 - end_pred_maximum_loss: 2.5559 - start_pred_maximum_accuracy: 0.3704 - end_pred_maximum_accuracy: 0.5305 - val_loss: 3.1623 - val_start_pred_maximum_loss: 1.7096 - val_end_pred_maximum_loss: 1.4527 - val_start_pred_maximum_accuracy: 0.6071 - val_end_pred_maximum_accuracy: 0.6928
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 7/25
# 507/507 [==============================] - 257s 506ms/step - loss: 6.1043 - start_pred_maximum_loss: 3.6071 - end_pred_maximum_loss: 2.4972 - start_pred_maximum_accuracy: 0.3803 - end_pred_maximum_accuracy: 0.5413 - val_loss: 3.1590 - val_start_pred_maximum_loss: 1.7151 - val_end_pred_maximum_loss: 1.4439 - val_start_pred_maximum_accuracy: 0.6051 - val_end_pred_maximum_accuracy: 0.6966
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 8/25
# 507/507 [==============================] - 257s 507ms/step - loss: 6.0107 - start_pred_maximum_loss: 3.5463 - end_pred_maximum_loss: 2.4644 - start_pred_maximum_accuracy: 0.3909 - end_pred_maximum_accuracy: 0.5503 - val_loss: 3.0397 - val_start_pred_maximum_loss: 1.6540 - val_end_pred_maximum_loss: 1.3856 - val_start_pred_maximum_accuracy: 0.6201 - val_end_pred_maximum_accuracy: 0.6973
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 9/25
# 507/507 [==============================] - 257s 506ms/step - loss: 5.9596 - start_pred_maximum_loss: 3.5366 - end_pred_maximum_loss: 2.4230 - start_pred_maximum_accuracy: 0.3946 - end_pred_maximum_accuracy: 0.5566 - val_loss: 2.9707 - val_start_pred_maximum_loss: 1.6237 - val_end_pred_maximum_loss: 1.3470 - val_start_pred_maximum_accuracy: 0.6154 - val_end_pred_maximum_accuracy: 0.7001
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 10/25
# 507/507 [==============================] - 257s 506ms/step - loss: 5.8643 - start_pred_maximum_loss: 3.5140 - end_pred_maximum_loss: 2.3504 - start_pred_maximum_accuracy: 0.3984 - end_pred_maximum_accuracy: 0.5714 - val_loss: 2.9760 - val_start_pred_maximum_loss: 1.6236 - val_end_pred_maximum_loss: 1.3524 - val_start_pred_maximum_accuracy: 0.6234 - val_end_pred_maximum_accuracy: 0.6963
#
# Epoch 00010: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 11/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.8084 - start_pred_maximum_loss: 3.4797 - end_pred_maximum_loss: 2.3286 - start_pred_maximum_accuracy: 0.4052 - end_pred_maximum_accuracy: 0.5739 - val_loss: 2.9484 - val_start_pred_maximum_loss: 1.6042 - val_end_pred_maximum_loss: 1.3442 - val_start_pred_maximum_accuracy: 0.6184 - val_end_pred_maximum_accuracy: 0.6969
#
# Epoch 00011: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 12/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.7410 - start_pred_maximum_loss: 3.4684 - end_pred_maximum_loss: 2.2726 - start_pred_maximum_accuracy: 0.4102 - end_pred_maximum_accuracy: 0.5844 - val_loss: 2.9102 - val_start_pred_maximum_loss: 1.5772 - val_end_pred_maximum_loss: 1.3331 - val_start_pred_maximum_accuracy: 0.6234 - val_end_pred_maximum_accuracy: 0.6952
#
# Epoch 00012: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 13/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.6764 - start_pred_maximum_loss: 3.4402 - end_pred_maximum_loss: 2.2362 - start_pred_maximum_accuracy: 0.4161 - end_pred_maximum_accuracy: 0.5903 - val_loss: 2.9147 - val_start_pred_maximum_loss: 1.5797 - val_end_pred_maximum_loss: 1.3350 - val_start_pred_maximum_accuracy: 0.6259 - val_end_pred_maximum_accuracy: 0.6943
#
# Epoch 00013: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 14/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.6230 - start_pred_maximum_loss: 3.4114 - end_pred_maximum_loss: 2.2115 - start_pred_maximum_accuracy: 0.4202 - end_pred_maximum_accuracy: 0.5949 - val_loss: 2.8940 - val_start_pred_maximum_loss: 1.5897 - val_end_pred_maximum_loss: 1.3043 - val_start_pred_maximum_accuracy: 0.6293 - val_end_pred_maximum_accuracy: 0.6986
#
# Epoch 00014: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 15/25
# 507/507 [==============================] - 260s 513ms/step - loss: 5.5950 - start_pred_maximum_loss: 3.4032 - end_pred_maximum_loss: 2.1919 - start_pred_maximum_accuracy: 0.4229 - end_pred_maximum_accuracy: 0.5987 - val_loss: 2.9512 - val_start_pred_maximum_loss: 1.5998 - val_end_pred_maximum_loss: 1.3513 - val_start_pred_maximum_accuracy: 0.6254 - val_end_pred_maximum_accuracy: 0.6918
#
# Epoch 00015: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 16/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.5377 - start_pred_maximum_loss: 3.3767 - end_pred_maximum_loss: 2.1610 - start_pred_maximum_accuracy: 0.4280 - end_pred_maximum_accuracy: 0.6045 - val_loss: 2.9571 - val_start_pred_maximum_loss: 1.5810 - val_end_pred_maximum_loss: 1.3761 - val_start_pred_maximum_accuracy: 0.6270 - val_end_pred_maximum_accuracy: 0.6921
#
# Epoch 00016: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 17/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.5424 - start_pred_maximum_loss: 3.3879 - end_pred_maximum_loss: 2.1545 - start_pred_maximum_accuracy: 0.4270 - end_pred_maximum_accuracy: 0.6074 - val_loss: 2.9484 - val_start_pred_maximum_loss: 1.5909 - val_end_pred_maximum_loss: 1.3575 - val_start_pred_maximum_accuracy: 0.6240 - val_end_pred_maximum_accuracy: 0.6903
#
# Epoch 00017: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 18/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.4896 - start_pred_maximum_loss: 3.3591 - end_pred_maximum_loss: 2.1305 - start_pred_maximum_accuracy: 0.4340 - end_pred_maximum_accuracy: 0.6101 - val_loss: 2.9281 - val_start_pred_maximum_loss: 1.5836 - val_end_pred_maximum_loss: 1.3444 - val_start_pred_maximum_accuracy: 0.6156 - val_end_pred_maximum_accuracy: 0.6940
#
# Epoch 00018: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 19/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.4305 - start_pred_maximum_loss: 3.3255 - end_pred_maximum_loss: 2.1050 - start_pred_maximum_accuracy: 0.4392 - end_pred_maximum_accuracy: 0.6150 - val_loss: 3.0194 - val_start_pred_maximum_loss: 1.5993 - val_end_pred_maximum_loss: 1.4201 - val_start_pred_maximum_accuracy: 0.6191 - val_end_pred_maximum_accuracy: 0.6877
#
# Epoch 00019: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 20/25
# 507/507 [==============================] - 257s 506ms/step - loss: 5.3762 - start_pred_maximum_loss: 3.3258 - end_pred_maximum_loss: 2.0505 - start_pred_maximum_accuracy: 0.4410 - end_pred_maximum_accuracy: 0.6251 - val_loss: 2.9743 - val_start_pred_maximum_loss: 1.5689 - val_end_pred_maximum_loss: 1.4054 - val_start_pred_maximum_accuracy: 0.6378 - val_end_pred_maximum_accuracy: 0.6905
#
# Epoch 00020: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 21/25
# 507/507 [==============================] - 257s 506ms/step - loss: 5.3800 - start_pred_maximum_loss: 3.3195 - end_pred_maximum_loss: 2.0604 - start_pred_maximum_accuracy: 0.4414 - end_pred_maximum_accuracy: 0.6241 - val_loss: 3.0185 - val_start_pred_maximum_loss: 1.5813 - val_end_pred_maximum_loss: 1.4372 - val_start_pred_maximum_accuracy: 0.6282 - val_end_pred_maximum_accuracy: 0.6884
#
# Epoch 00021: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 22/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.3384 - start_pred_maximum_loss: 3.2944 - end_pred_maximum_loss: 2.0439 - start_pred_maximum_accuracy: 0.4481 - end_pred_maximum_accuracy: 0.6275 - val_loss: 3.0706 - val_start_pred_maximum_loss: 1.5990 - val_end_pred_maximum_loss: 1.4716 - val_start_pred_maximum_accuracy: 0.6224 - val_end_pred_maximum_accuracy: 0.6847
#
# Epoch 00022: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 23/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.3161 - start_pred_maximum_loss: 3.2917 - end_pred_maximum_loss: 2.0243 - start_pred_maximum_accuracy: 0.4479 - end_pred_maximum_accuracy: 0.6280 - val_loss: 3.0620 - val_start_pred_maximum_loss: 1.5868 - val_end_pred_maximum_loss: 1.4752 - val_start_pred_maximum_accuracy: 0.6322 - val_end_pred_maximum_accuracy: 0.6845
#
# Epoch 00023: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 24/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.2801 - start_pred_maximum_loss: 3.2680 - end_pred_maximum_loss: 2.0122 - start_pred_maximum_accuracy: 0.4536 - end_pred_maximum_accuracy: 0.6304 - val_loss: 3.1537 - val_start_pred_maximum_loss: 1.6346 - val_end_pred_maximum_loss: 1.5191 - val_start_pred_maximum_accuracy: 0.6224 - val_end_pred_maximum_accuracy: 0.6855
#
# Epoch 00024: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5
# Epoch 25/25
# 507/507 [==============================] - 257s 507ms/step - loss: 5.2415 - start_pred_maximum_loss: 3.2565 - end_pred_maximum_loss: 1.9849 - start_pred_maximum_accuracy: 0.4567 - end_pred_maximum_accuracy: 0.6347 - val_loss: 3.1437 - val_start_pred_maximum_loss: 1.6146 - val_end_pred_maximum_loss: 1.5290 - val_start_pred_maximum_accuracy: 0.6322 - val_end_pred_maximum_accuracy: 0.6855
#
# Epoch 00025: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_maximum.hdf5

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'start_pred_maximum_loss', 'end_pred_maximum_loss', 'start_pred_maximum_accuracy', 'end_pred_maximum_accuracy', 'val_loss', 'val_start_pred_maximum_loss', 'val_end_pred_maximum_loss', 'val_start_pred_maximum_accuracy', 'val_end_pred_maximum_accuracy'])

# %%
# summarize history for accuracy
plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["end_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_end_pred_" + layer_option + "_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_accuracy", "end_pred_" + layer_option + "_accuracy", "val_start_pred_" + layer_option + "_accuracy", "val_end_pred_" + layer_option + "_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history["start_pred_" + layer_option + "_loss"])
plt.plot(history.history["end_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_start_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_end_pred_" + layer_option + "_loss"])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_loss", "end_pred_" + layer_option + "_loss", "val_start_pred_" + layer_option + "_loss", "val_end_pred_" + layer_option + "_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # Add

# %%
layer_option = "add"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]

# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_custom(model_name, custom_layer=layer_option, inputs=inputs)

model.compile(optimizer=optimizer, loss=[loss, loss], metrics=[accuracy])
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

model.summary()
# Out:
# DEBUG:filelock:Attempting to acquire lock 140390571334672 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140390571334672 acquired on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140390571334672 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140390571334672 released on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_add (Dense)         (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_add (Dense)           (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_add[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_add[0][0]
# __________________________________________________________________________________________________
# flatten_start_add (Flatten)     (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_add (Flatten)       (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 512)          0           flatten_start_add[0][0]
#                                                                  flatten_int_add[0][0]
# __________________________________________________________________________________________________
# start_pred_add (Activation)     (None, 512)          0           flatten_start_add[0][0]
# __________________________________________________________________________________________________
# end_pred_add (Activation)       (None, 512)          0           add_1[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=40,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/40
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 8.0909 - start_pred_add_loss: 4.3798 - end_pred_add_loss: 3.7111 - start_pred_add_accuracy: 0.2525 - end_pred_add_accuracy: 0.2793
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 422s 663ms/step - loss: 8.0909 - start_pred_add_loss: 4.3798 - end_pred_add_loss: 3.7111 - start_pred_add_accuracy: 0.2525 - end_pred_add_accuracy: 0.2793 - val_loss: 3.8955 - val_start_pred_add_loss: 2.3644 - val_end_pred_add_loss: 1.5311 - val_start_pred_add_accuracy: 0.5608 - val_end_pred_add_accuracy: 0.6192
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 2/40
# 507/507 [==============================] - 256s 506ms/step - loss: 6.8240 - start_pred_add_loss: 3.8313 - end_pred_add_loss: 2.9926 - start_pred_add_accuracy: 0.3489 - end_pred_add_accuracy: 0.4176 - val_loss: 3.3862 - val_start_pred_add_loss: 2.0682 - val_end_pred_add_loss: 1.3180 - val_start_pred_add_accuracy: 0.6040 - val_end_pred_add_accuracy: 0.6601
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 3/40
# 507/507 [==============================] - 256s 506ms/step - loss: 6.5300 - start_pred_add_loss: 3.7259 - end_pred_add_loss: 2.8041 - start_pred_add_accuracy: 0.3658 - end_pred_add_accuracy: 0.4555 - val_loss: 3.1743 - val_start_pred_add_loss: 1.9182 - val_end_pred_add_loss: 1.2560 - val_start_pred_add_accuracy: 0.6187 - val_end_pred_add_accuracy: 0.6780
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 4/40
# 507/507 [==============================] - 256s 505ms/step - loss: 6.3609 - start_pred_add_loss: 3.6828 - end_pred_add_loss: 2.6781 - start_pred_add_accuracy: 0.3732 - end_pred_add_accuracy: 0.4804 - val_loss: 3.1154 - val_start_pred_add_loss: 1.9257 - val_end_pred_add_loss: 1.1896 - val_start_pred_add_accuracy: 0.6315 - val_end_pred_add_accuracy: 0.6875
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 5/40
# 507/507 [==============================] - 257s 506ms/step - loss: 6.2124 - start_pred_add_loss: 3.6257 - end_pred_add_loss: 2.5868 - start_pred_add_accuracy: 0.3849 - end_pred_add_accuracy: 0.4989 - val_loss: 2.9141 - val_start_pred_add_loss: 1.7307 - val_end_pred_add_loss: 1.1834 - val_start_pred_add_accuracy: 0.6439 - val_end_pred_add_accuracy: 0.6973
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 6/40
# 507/507 [==============================] - 256s 506ms/step - loss: 6.0774 - start_pred_add_loss: 3.5895 - end_pred_add_loss: 2.4878 - start_pred_add_accuracy: 0.3888 - end_pred_add_accuracy: 0.5168 - val_loss: 2.9094 - val_start_pred_add_loss: 1.7475 - val_end_pred_add_loss: 1.1619 - val_start_pred_add_accuracy: 0.6438 - val_end_pred_add_accuracy: 0.6971
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 7/40
# 507/507 [==============================] - 256s 505ms/step - loss: 5.9790 - start_pred_add_loss: 3.5479 - end_pred_add_loss: 2.4311 - start_pred_add_accuracy: 0.3964 - end_pred_add_accuracy: 0.5289 - val_loss: 2.8828 - val_start_pred_add_loss: 1.7257 - val_end_pred_add_loss: 1.1571 - val_start_pred_add_accuracy: 0.6457 - val_end_pred_add_accuracy: 0.6996
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 8/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.8916 - start_pred_add_loss: 3.5182 - end_pred_add_loss: 2.3734 - start_pred_add_accuracy: 0.4036 - end_pred_add_accuracy: 0.5425 - val_loss: 2.8280 - val_start_pred_add_loss: 1.6466 - val_end_pred_add_loss: 1.1814 - val_start_pred_add_accuracy: 0.6486 - val_end_pred_add_accuracy: 0.6990
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 9/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.7951 - start_pred_add_loss: 3.4860 - end_pred_add_loss: 2.3091 - start_pred_add_accuracy: 0.4087 - end_pred_add_accuracy: 0.5537 - val_loss: 2.8033 - val_start_pred_add_loss: 1.6022 - val_end_pred_add_loss: 1.2011 - val_start_pred_add_accuracy: 0.6484 - val_end_pred_add_accuracy: 0.7022
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 10/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.7227 - start_pred_add_loss: 3.4631 - end_pred_add_loss: 2.2596 - start_pred_add_accuracy: 0.4126 - end_pred_add_accuracy: 0.5637 - val_loss: 2.8189 - val_start_pred_add_loss: 1.6100 - val_end_pred_add_loss: 1.2089 - val_start_pred_add_accuracy: 0.6500 - val_end_pred_add_accuracy: 0.7021
#
# Epoch 00010: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 11/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.6213 - start_pred_add_loss: 3.4333 - end_pred_add_loss: 2.1880 - start_pred_add_accuracy: 0.4154 - end_pred_add_accuracy: 0.5754 - val_loss: 2.7724 - val_start_pred_add_loss: 1.5746 - val_end_pred_add_loss: 1.1978 - val_start_pred_add_accuracy: 0.6531 - val_end_pred_add_accuracy: 0.7033
#
# Epoch 00011: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 12/40
# 507/507 [==============================] - 256s 505ms/step - loss: 5.5552 - start_pred_add_loss: 3.4083 - end_pred_add_loss: 2.1470 - start_pred_add_accuracy: 0.4214 - end_pred_add_accuracy: 0.5846 - val_loss: 2.8244 - val_start_pred_add_loss: 1.5770 - val_end_pred_add_loss: 1.2474 - val_start_pred_add_accuracy: 0.6479 - val_end_pred_add_accuracy: 0.6971
#
# Epoch 00012: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 13/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.5212 - start_pred_add_loss: 3.4160 - end_pred_add_loss: 2.1052 - start_pred_add_accuracy: 0.4203 - end_pred_add_accuracy: 0.5926 - val_loss: 2.8830 - val_start_pred_add_loss: 1.5649 - val_end_pred_add_loss: 1.3181 - val_start_pred_add_accuracy: 0.6456 - val_end_pred_add_accuracy: 0.6987
#
# Epoch 00013: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 14/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.4330 - start_pred_add_loss: 3.3795 - end_pred_add_loss: 2.0535 - start_pred_add_accuracy: 0.4263 - end_pred_add_accuracy: 0.6035 - val_loss: 2.9322 - val_start_pred_add_loss: 1.5140 - val_end_pred_add_loss: 1.4182 - val_start_pred_add_accuracy: 0.6513 - val_end_pred_add_accuracy: 0.6983
#
# Epoch 00014: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 15/40
# 507/507 [==============================] - 256s 505ms/step - loss: 5.3737 - start_pred_add_loss: 3.3640 - end_pred_add_loss: 2.0097 - start_pred_add_accuracy: 0.4297 - end_pred_add_accuracy: 0.6121 - val_loss: 2.9988 - val_start_pred_add_loss: 1.5188 - val_end_pred_add_loss: 1.4800 - val_start_pred_add_accuracy: 0.6425 - val_end_pred_add_accuracy: 0.6984
#
# Epoch 00015: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 16/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.3218 - start_pred_add_loss: 3.3487 - end_pred_add_loss: 1.9732 - start_pred_add_accuracy: 0.4318 - end_pred_add_accuracy: 0.6184 - val_loss: 2.9825 - val_start_pred_add_loss: 1.5236 - val_end_pred_add_loss: 1.4589 - val_start_pred_add_accuracy: 0.6449 - val_end_pred_add_accuracy: 0.6975
#
# Epoch 00016: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 17/40
# 507/507 [==============================] - 256s 505ms/step - loss: 5.2855 - start_pred_add_loss: 3.3420 - end_pred_add_loss: 1.9435 - start_pred_add_accuracy: 0.4336 - end_pred_add_accuracy: 0.6247 - val_loss: 3.0430 - val_start_pred_add_loss: 1.5428 - val_end_pred_add_loss: 1.5002 - val_start_pred_add_accuracy: 0.6461 - val_end_pred_add_accuracy: 0.6981
#
# Epoch 00017: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 18/40
# 507/507 [==============================] - 256s 505ms/step - loss: 5.2397 - start_pred_add_loss: 3.3263 - end_pred_add_loss: 1.9134 - start_pred_add_accuracy: 0.4375 - end_pred_add_accuracy: 0.6293 - val_loss: 3.0712 - val_start_pred_add_loss: 1.5521 - val_end_pred_add_loss: 1.5191 - val_start_pred_add_accuracy: 0.6452 - val_end_pred_add_accuracy: 0.6939
#
# Epoch 00018: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 19/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.2053 - start_pred_add_loss: 3.3269 - end_pred_add_loss: 1.8784 - start_pred_add_accuracy: 0.4371 - end_pred_add_accuracy: 0.6351 - val_loss: 3.0692 - val_start_pred_add_loss: 1.4846 - val_end_pred_add_loss: 1.5846 - val_start_pred_add_accuracy: 0.6521 - val_end_pred_add_accuracy: 0.6953
#
# Epoch 00019: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 20/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.1575 - start_pred_add_loss: 3.3032 - end_pred_add_loss: 1.8543 - start_pred_add_accuracy: 0.4414 - end_pred_add_accuracy: 0.6410 - val_loss: 3.2139 - val_start_pred_add_loss: 1.5064 - val_end_pred_add_loss: 1.7075 - val_start_pred_add_accuracy: 0.6460 - val_end_pred_add_accuracy: 0.6931
#
# Epoch 00020: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 21/40
# 507/507 [==============================] - 257s 506ms/step - loss: 5.1022 - start_pred_add_loss: 3.2845 - end_pred_add_loss: 1.8178 - start_pred_add_accuracy: 0.4454 - end_pred_add_accuracy: 0.6470 - val_loss: 3.2480 - val_start_pred_add_loss: 1.5285 - val_end_pred_add_loss: 1.7195 - val_start_pred_add_accuracy: 0.6444 - val_end_pred_add_accuracy: 0.6924
#
# Epoch 00021: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 22/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.0709 - start_pred_add_loss: 3.2718 - end_pred_add_loss: 1.7991 - start_pred_add_accuracy: 0.4473 - end_pred_add_accuracy: 0.6500 - val_loss: 3.3210 - val_start_pred_add_loss: 1.4835 - val_end_pred_add_loss: 1.8375 - val_start_pred_add_accuracy: 0.6509 - val_end_pred_add_accuracy: 0.6903
#
# Epoch 00022: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 23/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.0437 - start_pred_add_loss: 3.2571 - end_pred_add_loss: 1.7866 - start_pred_add_accuracy: 0.4509 - end_pred_add_accuracy: 0.6530 - val_loss: 3.3714 - val_start_pred_add_loss: 1.4723 - val_end_pred_add_loss: 1.8991 - val_start_pred_add_accuracy: 0.6518 - val_end_pred_add_accuracy: 0.6896
#
# Epoch 00023: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 24/40
# 507/507 [==============================] - 256s 506ms/step - loss: 5.0199 - start_pred_add_loss: 3.2482 - end_pred_add_loss: 1.7717 - start_pred_add_accuracy: 0.4530 - end_pred_add_accuracy: 0.6556 - val_loss: 3.3839 - val_start_pred_add_loss: 1.5019 - val_end_pred_add_loss: 1.8820 - val_start_pred_add_accuracy: 0.6468 - val_end_pred_add_accuracy: 0.6926
#
# Epoch 00024: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 25/40
# 507/507 [==============================] - 257s 506ms/step - loss: 4.9751 - start_pred_add_loss: 3.2277 - end_pred_add_loss: 1.7474 - start_pred_add_accuracy: 0.4558 - end_pred_add_accuracy: 0.6615 - val_loss: 3.4061 - val_start_pred_add_loss: 1.5135 - val_end_pred_add_loss: 1.8926 - val_start_pred_add_accuracy: 0.6469 - val_end_pred_add_accuracy: 0.6927
#
# Epoch 00025: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 26/40
# 507/507 [==============================] - 257s 506ms/step - loss: 4.9845 - start_pred_add_loss: 3.2457 - end_pred_add_loss: 1.7388 - start_pred_add_accuracy: 0.4533 - end_pred_add_accuracy: 0.6615 - val_loss: 3.5298 - val_start_pred_add_loss: 1.5100 - val_end_pred_add_loss: 2.0198 - val_start_pred_add_accuracy: 0.6465 - val_end_pred_add_accuracy: 0.6921
#
# Epoch 00026: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 27/40
# 507/507 [==============================] - 257s 506ms/step - loss: 4.9425 - start_pred_add_loss: 3.2276 - end_pred_add_loss: 1.7148 - start_pred_add_accuracy: 0.4573 - end_pred_add_accuracy: 0.6683 - val_loss: 3.5729 - val_start_pred_add_loss: 1.5220 - val_end_pred_add_loss: 2.0510 - val_start_pred_add_accuracy: 0.6486 - val_end_pred_add_accuracy: 0.6881
#
# Epoch 00027: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 28/40
# 507/507 [==============================] - 256s 505ms/step - loss: 4.9047 - start_pred_add_loss: 3.2053 - end_pred_add_loss: 1.6994 - start_pred_add_accuracy: 0.4607 - end_pred_add_accuracy: 0.6701 - val_loss: 3.6014 - val_start_pred_add_loss: 1.5418 - val_end_pred_add_loss: 2.0595 - val_start_pred_add_accuracy: 0.6428 - val_end_pred_add_accuracy: 0.6894
#
# Epoch 00028: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 29/40
# 507/507 [==============================] - 256s 505ms/step - loss: 4.8955 - start_pred_add_loss: 3.2035 - end_pred_add_loss: 1.6920 - start_pred_add_accuracy: 0.4614 - end_pred_add_accuracy: 0.6719 - val_loss: 3.7928 - val_start_pred_add_loss: 1.5649 - val_end_pred_add_loss: 2.2279 - val_start_pred_add_accuracy: 0.6394 - val_end_pred_add_accuracy: 0.6864
#
# Epoch 00029: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 30/40
# 507/507 [==============================] - 257s 507ms/step - loss: 4.8630 - start_pred_add_loss: 3.1875 - end_pred_add_loss: 1.6754 - start_pred_add_accuracy: 0.4656 - end_pred_add_accuracy: 0.6748 - val_loss: 3.6531 - val_start_pred_add_loss: 1.5427 - val_end_pred_add_loss: 2.1104 - val_start_pred_add_accuracy: 0.6442 - val_end_pred_add_accuracy: 0.6873
#
# Epoch 00030: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 31/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.8470 - start_pred_add_loss: 3.1776 - end_pred_add_loss: 1.6694 - start_pred_add_accuracy: 0.4670 - end_pred_add_accuracy: 0.6755 - val_loss: 3.8905 - val_start_pred_add_loss: 1.5805 - val_end_pred_add_loss: 2.3100 - val_start_pred_add_accuracy: 0.6466 - val_end_pred_add_accuracy: 0.6884
#
# Epoch 00031: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 32/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.8223 - start_pred_add_loss: 3.1670 - end_pred_add_loss: 1.6554 - start_pred_add_accuracy: 0.4702 - end_pred_add_accuracy: 0.6777 - val_loss: 3.9296 - val_start_pred_add_loss: 1.5726 - val_end_pred_add_loss: 2.3570 - val_start_pred_add_accuracy: 0.6423 - val_end_pred_add_accuracy: 0.6868
#
# Epoch 00032: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 33/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.8232 - start_pred_add_loss: 3.1637 - end_pred_add_loss: 1.6595 - start_pred_add_accuracy: 0.4708 - end_pred_add_accuracy: 0.6773 - val_loss: 3.7856 - val_start_pred_add_loss: 1.5700 - val_end_pred_add_loss: 2.2156 - val_start_pred_add_accuracy: 0.6443 - val_end_pred_add_accuracy: 0.6872
#
# Epoch 00033: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 34/40
# 507/507 [==============================] - 257s 506ms/step - loss: 4.8025 - start_pred_add_loss: 3.1612 - end_pred_add_loss: 1.6414 - start_pred_add_accuracy: 0.4714 - end_pred_add_accuracy: 0.6810 - val_loss: 3.9901 - val_start_pred_add_loss: 1.5655 - val_end_pred_add_loss: 2.4247 - val_start_pred_add_accuracy: 0.6458 - val_end_pred_add_accuracy: 0.6898
#
# Epoch 00034: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 35/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.7902 - start_pred_add_loss: 3.1615 - end_pred_add_loss: 1.6286 - start_pred_add_accuracy: 0.4705 - end_pred_add_accuracy: 0.6845 - val_loss: 4.0576 - val_start_pred_add_loss: 1.6152 - val_end_pred_add_loss: 2.4424 - val_start_pred_add_accuracy: 0.6369 - val_end_pred_add_accuracy: 0.6886
#
# Epoch 00035: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 36/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.7569 - start_pred_add_loss: 3.1389 - end_pred_add_loss: 1.6180 - start_pred_add_accuracy: 0.4746 - end_pred_add_accuracy: 0.6863 - val_loss: 3.9556 - val_start_pred_add_loss: 1.5900 - val_end_pred_add_loss: 2.3656 - val_start_pred_add_accuracy: 0.6439 - val_end_pred_add_accuracy: 0.6887
#
# Epoch 00036: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 37/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.7162 - start_pred_add_loss: 3.1172 - end_pred_add_loss: 1.5990 - start_pred_add_accuracy: 0.4795 - end_pred_add_accuracy: 0.6892 - val_loss: 4.1113 - val_start_pred_add_loss: 1.6406 - val_end_pred_add_loss: 2.4707 - val_start_pred_add_accuracy: 0.6448 - val_end_pred_add_accuracy: 0.6912
#
# Epoch 00037: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 38/40
# 507/507 [==============================] - 257s 506ms/step - loss: 4.7678 - start_pred_add_loss: 3.1440 - end_pred_add_loss: 1.6239 - start_pred_add_accuracy: 0.4750 - end_pred_add_accuracy: 0.6861 - val_loss: 4.1889 - val_start_pred_add_loss: 1.6721 - val_end_pred_add_loss: 2.5169 - val_start_pred_add_accuracy: 0.6426 - val_end_pred_add_accuracy: 0.6880
#
# Epoch 00038: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 39/40
# 507/507 [==============================] - 256s 506ms/step - loss: 4.7178 - start_pred_add_loss: 3.1207 - end_pred_add_loss: 1.5972 - start_pred_add_accuracy: 0.4793 - end_pred_add_accuracy: 0.6898 - val_loss: 4.1536 - val_start_pred_add_loss: 1.6675 - val_end_pred_add_loss: 2.4861 - val_start_pred_add_accuracy: 0.6394 - val_end_pred_add_accuracy: 0.6897
#
# Epoch 00039: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5
# Epoch 40/40
# 507/507 [==============================] - 257s 506ms/step - loss: 4.7123 - start_pred_add_loss: 3.1202 - end_pred_add_loss: 1.5922 - start_pred_add_accuracy: 0.4788 - end_pred_add_accuracy: 0.6917 - val_loss: 4.2544 - val_start_pred_add_loss: 1.6705 - val_end_pred_add_loss: 2.5838 - val_start_pred_add_accuracy: 0.6435 - val_end_pred_add_accuracy: 0.6890
#
# Epoch 00040: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_add.hdf5

# %%
history.history.keys()

# %%
# summarize history for accuracy
plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["end_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_end_pred_" + layer_option + "_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_accuracy", "end_pred_" + layer_option + "_accuracy", "val_start_pred_" + layer_option + "_accuracy", "val_end_pred_" + layer_option + "_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history["start_pred_" + layer_option + "_loss"])
plt.plot(history.history["end_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_start_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_end_pred_" + layer_option + "_loss"])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_loss", "end_pred_" + layer_option + "_loss", "val_start_pred_" + layer_option + "_loss", "val_end_pred_" + layer_option + "_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # Minimum

# %%
layer_option = "minimum"

# %%
# Create distribution strategy
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
strategy = tf.distribute.TPUStrategy(tpu)

ES_start = EarlyStopping(monitor='val_start_pred_' + layer_option + '_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)
ES_end = EarlyStopping(monitor='val_end_pred_' + layer_option + '_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)

# def accuracy(y_true, y_pred):
#     sampled = tf.argmax(y_pred, axis=-1)
#     if len(sampled)==0:
#         return np.float64(1)   
#     acc = 1 - tf.math.count_nonzero(tf.squeeze(tf.cast(y_true, tf.int64)) - sampled) / tf.cast(len(sampled), tf.int64)
#     return acc

# Save the slow pretrained tokenizer
path = '/content/drive/MyDrive/NLP/proj finale/dataset'

loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = keras.optimizers.Adam(lr=1e-5, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]
# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_custom(model_name, custom_layer=layer_option, inputs=inputs)

model.compile(optimizer=optimizer, loss=[loss, loss], metrics=[accuracy])
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

model.summary()
# Out:
# DEBUG:filelock:Attempting to acquire lock 139906051544912 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 139906051544912 acquired on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139906051544912 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 139906051544912 released on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_minimum (Dense)     (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_minimum (Dense)       (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_minimum[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_minimum[0][0]
# __________________________________________________________________________________________________
# flatten_start_minimum (Flatten) (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_minimum (Flatten)   (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# minimum (Minimum)               (None, 512)          0           flatten_start_minimum[0][0]
#                                                                  flatten_int_minimum[0][0]
# __________________________________________________________________________________________________
# start_pred_minimum (Activation) (None, 512)          0           flatten_start_minimum[0][0]
# __________________________________________________________________________________________________
# end_pred_minimum (Activation)   (None, 512)          0           minimum[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=30,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/30
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 9.0727 - start_pred_minimum_loss: 4.3704 - end_pred_minimum_loss: 4.7023 - start_pred_minimum_accuracy: 0.2492 - end_pred_minimum_accuracy: 0.1451
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 422s 660ms/step - loss: 9.0727 - start_pred_minimum_loss: 4.3704 - end_pred_minimum_loss: 4.7023 - start_pred_minimum_accuracy: 0.2492 - end_pred_minimum_accuracy: 0.1451 - val_loss: 4.2839 - val_start_pred_minimum_loss: 2.1308 - val_end_pred_minimum_loss: 2.1531 - val_start_pred_minimum_accuracy: 0.5572 - val_end_pred_minimum_accuracy: 0.5659
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 2/30
# 507/507 [==============================] - 257s 507ms/step - loss: 8.1268 - start_pred_minimum_loss: 3.8304 - end_pred_minimum_loss: 4.2964 - start_pred_minimum_accuracy: 0.3490 - end_pred_minimum_accuracy: 0.2007 - val_loss: 3.6361 - val_start_pred_minimum_loss: 1.8319 - val_end_pred_minimum_loss: 1.8042 - val_start_pred_minimum_accuracy: 0.6065 - val_end_pred_minimum_accuracy: 0.6231
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 3/30
# 507/507 [==============================] - 257s 506ms/step - loss: 7.9125 - start_pred_minimum_loss: 3.7118 - end_pred_minimum_loss: 4.2007 - start_pred_minimum_accuracy: 0.3681 - end_pred_minimum_accuracy: 0.2123 - val_loss: 3.2941 - val_start_pred_minimum_loss: 1.6760 - val_end_pred_minimum_loss: 1.6181 - val_start_pred_minimum_accuracy: 0.6245 - val_end_pred_minimum_accuracy: 0.6530
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 4/30
# 507/507 [==============================] - 257s 506ms/step - loss: 7.7824 - start_pred_minimum_loss: 3.6293 - end_pred_minimum_loss: 4.1531 - start_pred_minimum_accuracy: 0.3808 - end_pred_minimum_accuracy: 0.2189 - val_loss: 3.2701 - val_start_pred_minimum_loss: 1.6416 - val_end_pred_minimum_loss: 1.6284 - val_start_pred_minimum_accuracy: 0.6387 - val_end_pred_minimum_accuracy: 0.6599
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 5/30
# 507/507 [==============================] - 257s 506ms/step - loss: 7.6648 - start_pred_minimum_loss: 3.5508 - end_pred_minimum_loss: 4.1140 - start_pred_minimum_accuracy: 0.3945 - end_pred_minimum_accuracy: 0.2223 - val_loss: 2.9297 - val_start_pred_minimum_loss: 1.4999 - val_end_pred_minimum_loss: 1.4298 - val_start_pred_minimum_accuracy: 0.6456 - val_end_pred_minimum_accuracy: 0.6716
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 6/30
# 507/507 [==============================] - 257s 506ms/step - loss: 7.5633 - start_pred_minimum_loss: 3.4819 - end_pred_minimum_loss: 4.0814 - start_pred_minimum_accuracy: 0.4076 - end_pred_minimum_accuracy: 0.2275 - val_loss: 2.8887 - val_start_pred_minimum_loss: 1.4786 - val_end_pred_minimum_loss: 1.4101 - val_start_pred_minimum_accuracy: 0.6451 - val_end_pred_minimum_accuracy: 0.6793
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 7/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.5452 - start_pred_minimum_loss: 3.4759 - end_pred_minimum_loss: 4.0693 - start_pred_minimum_accuracy: 0.4089 - end_pred_minimum_accuracy: 0.2278 - val_loss: 2.8602 - val_start_pred_minimum_loss: 1.4804 - val_end_pred_minimum_loss: 1.3798 - val_start_pred_minimum_accuracy: 0.6479 - val_end_pred_minimum_accuracy: 0.6793
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 8/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.4974 - start_pred_minimum_loss: 3.4459 - end_pred_minimum_loss: 4.0516 - start_pred_minimum_accuracy: 0.4126 - end_pred_minimum_accuracy: 0.2298 - val_loss: 2.6859 - val_start_pred_minimum_loss: 1.3995 - val_end_pred_minimum_loss: 1.2864 - val_start_pred_minimum_accuracy: 0.6524 - val_end_pred_minimum_accuracy: 0.6858
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 9/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.4393 - start_pred_minimum_loss: 3.3964 - end_pred_minimum_loss: 4.0430 - start_pred_minimum_accuracy: 0.4210 - end_pred_minimum_accuracy: 0.2299 - val_loss: 2.6686 - val_start_pred_minimum_loss: 1.3826 - val_end_pred_minimum_loss: 1.2860 - val_start_pred_minimum_accuracy: 0.6556 - val_end_pred_minimum_accuracy: 0.6839
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 10/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.3988 - start_pred_minimum_loss: 3.3805 - end_pred_minimum_loss: 4.0183 - start_pred_minimum_accuracy: 0.4229 - end_pred_minimum_accuracy: 0.2318 - val_loss: 2.6389 - val_start_pred_minimum_loss: 1.3802 - val_end_pred_minimum_loss: 1.2587 - val_start_pred_minimum_accuracy: 0.6539 - val_end_pred_minimum_accuracy: 0.6855
#
# Epoch 00010: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 11/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.3328 - start_pred_minimum_loss: 3.3397 - end_pred_minimum_loss: 3.9931 - start_pred_minimum_accuracy: 0.4318 - end_pred_minimum_accuracy: 0.2369 - val_loss: 2.6220 - val_start_pred_minimum_loss: 1.3892 - val_end_pred_minimum_loss: 1.2328 - val_start_pred_minimum_accuracy: 0.6540 - val_end_pred_minimum_accuracy: 0.6899
#
# Epoch 00011: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 12/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.2965 - start_pred_minimum_loss: 3.2995 - end_pred_minimum_loss: 3.9969 - start_pred_minimum_accuracy: 0.4370 - end_pred_minimum_accuracy: 0.2336 - val_loss: 2.6449 - val_start_pred_minimum_loss: 1.3965 - val_end_pred_minimum_loss: 1.2484 - val_start_pred_minimum_accuracy: 0.6521 - val_end_pred_minimum_accuracy: 0.6896
#
# Epoch 00012: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 13/30
# 507/507 [==============================] - 257s 507ms/step - loss: 7.2499 - start_pred_minimum_loss: 3.2800 - end_pred_minimum_loss: 3.9699 - start_pred_minimum_accuracy: 0.4415 - end_pred_minimum_accuracy: 0.2395 - val_loss: 2.5748 - val_start_pred_minimum_loss: 1.3783 - val_end_pred_minimum_loss: 1.1966 - val_start_pred_minimum_accuracy: 0.6552 - val_end_pred_minimum_accuracy: 0.6896
# Restoring model weights from the end of the best epoch.
#
# Epoch 00013: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_minimum.hdf5
# Epoch 00013: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'start_pred_minimum_loss', 'end_pred_minimum_loss', 'start_pred_minimum_accuracy', 'end_pred_minimum_accuracy', 'val_loss', 'val_start_pred_minimum_loss', 'val_end_pred_minimum_loss', 'val_start_pred_minimum_accuracy', 'val_end_pred_minimum_accuracy'])

# %%
# summarize history for accuracy
plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["end_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_start_pred_" + layer_option + "_accuracy"])
plt.plot(history.history["val_end_pred_" + layer_option + "_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_accuracy", "end_pred_" + layer_option + "_accuracy", "val_start_pred_" + layer_option + "_accuracy", "val_end_pred_" + layer_option + "_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history["start_pred_" + layer_option + "_loss"])
plt.plot(history.history["end_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_start_pred_" + layer_option + "_loss"])
plt.plot(history.history["val_end_pred_" + layer_option + "_loss"])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(["start_pred_" + layer_option + "_loss", "end_pred_" + layer_option + "_loss", "val_start_pred_" + layer_option + "_loss", "val_end_pred_" + layer_option + "_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # Subtract

# %%
layer_option = "subtract"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]

# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_custom(model_name, custom_layer=layer_option, inputs= inputs)

model.compile(optimizer=optimizer, loss=[loss, loss], metrics=[accuracy])
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

model.summary()
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_subtract (Dense)    (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_subtract (Dense)      (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_subtract[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_subtract[0][0]
# __________________________________________________________________________________________________
# flatten_start_subtract (Flatten (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_subtract (Flatten)  (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 512)          0           flatten_start_subtract[0][0]
#                                                                  flatten_int_subtract[0][0]
# __________________________________________________________________________________________________
# start_pred_subtract (Activation (None, 512)          0           flatten_start_subtract[0][0]
# __________________________________________________________________________________________________
# end_pred_subtract (Activation)  (None, 512)          0           subtract[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=25,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/25
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 8.1616 - start_pred_subtract_loss: 4.4104 - end_pred_subtract_loss: 3.7512 - start_pred_subtract_accuracy: 0.2450 - end_pred_subtract_accuracy: 0.2716
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 432s 668ms/step - loss: 8.1616 - start_pred_subtract_loss: 4.4104 - end_pred_subtract_loss: 3.7512 - start_pred_subtract_accuracy: 0.2450 - end_pred_subtract_accuracy: 0.2716 - val_loss: 3.9804 - val_start_pred_subtract_loss: 2.4751 - val_end_pred_subtract_loss: 1.5053 - val_start_pred_subtract_accuracy: 0.5498 - val_end_pred_subtract_accuracy: 0.6205
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 2/25
# 507/507 [==============================] - 259s 511ms/step - loss: 6.8173 - start_pred_subtract_loss: 3.8538 - end_pred_subtract_loss: 2.9635 - start_pred_subtract_accuracy: 0.3440 - end_pred_subtract_accuracy: 0.4186 - val_loss: 3.4357 - val_start_pred_subtract_loss: 2.1249 - val_end_pred_subtract_loss: 1.3107 - val_start_pred_subtract_accuracy: 0.5973 - val_end_pred_subtract_accuracy: 0.6581
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 3/25
# 507/507 [==============================] - 258s 510ms/step - loss: 6.5298 - start_pred_subtract_loss: 3.7384 - end_pred_subtract_loss: 2.7914 - start_pred_subtract_accuracy: 0.3628 - end_pred_subtract_accuracy: 0.4559 - val_loss: 3.1190 - val_start_pred_subtract_loss: 1.8900 - val_end_pred_subtract_loss: 1.2290 - val_start_pred_subtract_accuracy: 0.6145 - val_end_pred_subtract_accuracy: 0.6784
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 4/25
# 507/507 [==============================] - 259s 510ms/step - loss: 6.3362 - start_pred_subtract_loss: 3.6666 - end_pred_subtract_loss: 2.6696 - start_pred_subtract_accuracy: 0.3768 - end_pred_subtract_accuracy: 0.4817 - val_loss: 3.0234 - val_start_pred_subtract_loss: 1.8316 - val_end_pred_subtract_loss: 1.1918 - val_start_pred_subtract_accuracy: 0.6335 - val_end_pred_subtract_accuracy: 0.6852
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 5/25
# 507/507 [==============================] - 258s 510ms/step - loss: 6.1925 - start_pred_subtract_loss: 3.6131 - end_pred_subtract_loss: 2.5794 - start_pred_subtract_accuracy: 0.3872 - end_pred_subtract_accuracy: 0.4981 - val_loss: 2.8899 - val_start_pred_subtract_loss: 1.7283 - val_end_pred_subtract_loss: 1.1616 - val_start_pred_subtract_accuracy: 0.6399 - val_end_pred_subtract_accuracy: 0.6940
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 6/25
# 507/507 [==============================] - 258s 510ms/step - loss: 6.0572 - start_pred_subtract_loss: 3.5610 - end_pred_subtract_loss: 2.4962 - start_pred_subtract_accuracy: 0.3947 - end_pred_subtract_accuracy: 0.5149 - val_loss: 2.9043 - val_start_pred_subtract_loss: 1.7197 - val_end_pred_subtract_loss: 1.1846 - val_start_pred_subtract_accuracy: 0.6390 - val_end_pred_subtract_accuracy: 0.6946
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 7/25
# 507/507 [==============================] - 258s 510ms/step - loss: 5.9619 - start_pred_subtract_loss: 3.5362 - end_pred_subtract_loss: 2.4257 - start_pred_subtract_accuracy: 0.3998 - end_pred_subtract_accuracy: 0.5310 - val_loss: 2.8962 - val_start_pred_subtract_loss: 1.7155 - val_end_pred_subtract_loss: 1.1807 - val_start_pred_subtract_accuracy: 0.6390 - val_end_pred_subtract_accuracy: 0.6986
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 8/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.8607 - start_pred_subtract_loss: 3.5059 - end_pred_subtract_loss: 2.3548 - start_pred_subtract_accuracy: 0.4032 - end_pred_subtract_accuracy: 0.5419 - val_loss: 2.8607 - val_start_pred_subtract_loss: 1.6583 - val_end_pred_subtract_loss: 1.2024 - val_start_pred_subtract_accuracy: 0.6425 - val_end_pred_subtract_accuracy: 0.6983
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 9/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.7742 - start_pred_subtract_loss: 3.4762 - end_pred_subtract_loss: 2.2981 - start_pred_subtract_accuracy: 0.4107 - end_pred_subtract_accuracy: 0.5551 - val_loss: 2.8238 - val_start_pred_subtract_loss: 1.6062 - val_end_pred_subtract_loss: 1.2175 - val_start_pred_subtract_accuracy: 0.6486 - val_end_pred_subtract_accuracy: 0.7006
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 10/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.7190 - start_pred_subtract_loss: 3.4780 - end_pred_subtract_loss: 2.2409 - start_pred_subtract_accuracy: 0.4089 - end_pred_subtract_accuracy: 0.5671 - val_loss: 2.8635 - val_start_pred_subtract_loss: 1.6226 - val_end_pred_subtract_loss: 1.2409 - val_start_pred_subtract_accuracy: 0.6489 - val_end_pred_subtract_accuracy: 0.7016
#
# Epoch 00010: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 11/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.6160 - start_pred_subtract_loss: 3.4301 - end_pred_subtract_loss: 2.1859 - start_pred_subtract_accuracy: 0.4182 - end_pred_subtract_accuracy: 0.5762 - val_loss: 2.8887 - val_start_pred_subtract_loss: 1.6563 - val_end_pred_subtract_loss: 1.2324 - val_start_pred_subtract_accuracy: 0.6436 - val_end_pred_subtract_accuracy: 0.6989
#
# Epoch 00011: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 12/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.5433 - start_pred_subtract_loss: 3.4121 - end_pred_subtract_loss: 2.1313 - start_pred_subtract_accuracy: 0.4217 - end_pred_subtract_accuracy: 0.5874 - val_loss: 2.8845 - val_start_pred_subtract_loss: 1.5368 - val_end_pred_subtract_loss: 1.3477 - val_start_pred_subtract_accuracy: 0.6495 - val_end_pred_subtract_accuracy: 0.6969
#
# Epoch 00012: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 13/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.4893 - start_pred_subtract_loss: 3.3972 - end_pred_subtract_loss: 2.0921 - start_pred_subtract_accuracy: 0.4244 - end_pred_subtract_accuracy: 0.5945 - val_loss: 2.8745 - val_start_pred_subtract_loss: 1.5231 - val_end_pred_subtract_loss: 1.3514 - val_start_pred_subtract_accuracy: 0.6507 - val_end_pred_subtract_accuracy: 0.6968
#
# Epoch 00013: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 14/25
# 507/507 [==============================] - 261s 515ms/step - loss: 5.4315 - start_pred_subtract_loss: 3.3795 - end_pred_subtract_loss: 2.0520 - start_pred_subtract_accuracy: 0.4277 - end_pred_subtract_accuracy: 0.6027 - val_loss: 2.9087 - val_start_pred_subtract_loss: 1.5265 - val_end_pred_subtract_loss: 1.3821 - val_start_pred_subtract_accuracy: 0.6492 - val_end_pred_subtract_accuracy: 0.6986
#
# Epoch 00014: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 15/25
# 507/507 [==============================] - 259s 512ms/step - loss: 5.3872 - start_pred_subtract_loss: 3.3647 - end_pred_subtract_loss: 2.0225 - start_pred_subtract_accuracy: 0.4289 - end_pred_subtract_accuracy: 0.6089 - val_loss: 3.0398 - val_start_pred_subtract_loss: 1.5330 - val_end_pred_subtract_loss: 1.5068 - val_start_pred_subtract_accuracy: 0.6496 - val_end_pred_subtract_accuracy: 0.6985
#
# Epoch 00015: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 16/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.2890 - start_pred_subtract_loss: 3.3292 - end_pred_subtract_loss: 1.9598 - start_pred_subtract_accuracy: 0.4368 - end_pred_subtract_accuracy: 0.6195 - val_loss: 3.0267 - val_start_pred_subtract_loss: 1.4964 - val_end_pred_subtract_loss: 1.5303 - val_start_pred_subtract_accuracy: 0.6509 - val_end_pred_subtract_accuracy: 0.6978
#
# Epoch 00016: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 17/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.2692 - start_pred_subtract_loss: 3.3343 - end_pred_subtract_loss: 1.9349 - start_pred_subtract_accuracy: 0.4349 - end_pred_subtract_accuracy: 0.6223 - val_loss: 3.1030 - val_start_pred_subtract_loss: 1.5219 - val_end_pred_subtract_loss: 1.5811 - val_start_pred_subtract_accuracy: 0.6436 - val_end_pred_subtract_accuracy: 0.6958
#
# Epoch 00017: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 18/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.2273 - start_pred_subtract_loss: 3.3230 - end_pred_subtract_loss: 1.9043 - start_pred_subtract_accuracy: 0.4382 - end_pred_subtract_accuracy: 0.6311 - val_loss: 3.1714 - val_start_pred_subtract_loss: 1.4933 - val_end_pred_subtract_loss: 1.6781 - val_start_pred_subtract_accuracy: 0.6516 - val_end_pred_subtract_accuracy: 0.6962
#
# Epoch 00018: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 19/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.1730 - start_pred_subtract_loss: 3.3014 - end_pred_subtract_loss: 1.8716 - start_pred_subtract_accuracy: 0.4416 - end_pred_subtract_accuracy: 0.6364 - val_loss: 3.2885 - val_start_pred_subtract_loss: 1.5187 - val_end_pred_subtract_loss: 1.7698 - val_start_pred_subtract_accuracy: 0.6440 - val_end_pred_subtract_accuracy: 0.6933
#
# Epoch 00019: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 20/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.1301 - start_pred_subtract_loss: 3.2917 - end_pred_subtract_loss: 1.8385 - start_pred_subtract_accuracy: 0.4428 - end_pred_subtract_accuracy: 0.6412 - val_loss: 3.2615 - val_start_pred_subtract_loss: 1.5059 - val_end_pred_subtract_loss: 1.7556 - val_start_pred_subtract_accuracy: 0.6516 - val_end_pred_subtract_accuracy: 0.6938
#
# Epoch 00020: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 21/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.1183 - start_pred_subtract_loss: 3.2907 - end_pred_subtract_loss: 1.8277 - start_pred_subtract_accuracy: 0.4448 - end_pred_subtract_accuracy: 0.6447 - val_loss: 3.2943 - val_start_pred_subtract_loss: 1.5021 - val_end_pred_subtract_loss: 1.7923 - val_start_pred_subtract_accuracy: 0.6454 - val_end_pred_subtract_accuracy: 0.6959
#
# Epoch 00021: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 22/25
# 507/507 [==============================] - 259s 511ms/step - loss: 5.0789 - start_pred_subtract_loss: 3.2846 - end_pred_subtract_loss: 1.7944 - start_pred_subtract_accuracy: 0.4463 - end_pred_subtract_accuracy: 0.6510 - val_loss: 3.3787 - val_start_pred_subtract_loss: 1.5000 - val_end_pred_subtract_loss: 1.8787 - val_start_pred_subtract_accuracy: 0.6517 - val_end_pred_subtract_accuracy: 0.6954
#
# Epoch 00022: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 23/25
# 507/507 [==============================] - 260s 512ms/step - loss: 5.0402 - start_pred_subtract_loss: 3.2746 - end_pred_subtract_loss: 1.7656 - start_pred_subtract_accuracy: 0.4470 - end_pred_subtract_accuracy: 0.6549 - val_loss: 3.5162 - val_start_pred_subtract_loss: 1.4970 - val_end_pred_subtract_loss: 2.0192 - val_start_pred_subtract_accuracy: 0.6448 - val_end_pred_subtract_accuracy: 0.6901
#
# Epoch 00023: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 24/25
# 507/507 [==============================] - 259s 512ms/step - loss: 5.0160 - start_pred_subtract_loss: 3.2551 - end_pred_subtract_loss: 1.7609 - start_pred_subtract_accuracy: 0.4512 - end_pred_subtract_accuracy: 0.6566 - val_loss: 3.5449 - val_start_pred_subtract_loss: 1.4977 - val_end_pred_subtract_loss: 2.0472 - val_start_pred_subtract_accuracy: 0.6498 - val_end_pred_subtract_accuracy: 0.6934
#
# Epoch 00024: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5
# Epoch 25/25
# 507/507 [==============================] - 260s 512ms/step - loss: 4.9834 - start_pred_subtract_loss: 3.2385 - end_pred_subtract_loss: 1.7449 - start_pred_subtract_accuracy: 0.4543 - end_pred_subtract_accuracy: 0.6612 - val_loss: 3.6588 - val_start_pred_subtract_loss: 1.5331 - val_end_pred_subtract_loss: 2.1256 - val_start_pred_subtract_accuracy: 0.6441 - val_end_pred_subtract_accuracy: 0.6895
#
# Epoch 00025: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_subtract.hdf5

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'start_pred_subtract_loss', 'end_pred_subtract_loss', 'start_pred_subtract_accuracy', 'end_pred_subtract_accuracy', 'val_loss', 'val_start_pred_subtract_loss', 'val_end_pred_subtract_loss', 'val_start_pred_subtract_accuracy', 'val_end_pred_subtract_accuracy'])

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_subtract_accuracy"])
plt.plot(history.history["end_pred_subtract_accuracy"])
plt.plot(history.history["val_start_pred_subtract_accuracy"])
plt.plot(history.history["val_end_pred_subtract_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['start_pred_accuracy', 'end_pred_accuracy', "val_start_pred_accuracy", "val_end_pred_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history['start_pred_subtract_loss'])
plt.plot(history.history['end_pred_subtract_loss'])
plt.plot(history.history['val_start_pred_subtract_loss'])
plt.plot(history.history['val_end_pred_subtract_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['start_pred_loss', 'end_pred_loss', "val_start_pred_loss", "val_end_pred_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # Multiply

# %%
layer_option = "multiply"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]

# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_custom(model_name, custom_layer=layer_option, inputs = inputs)

model.summary()

model.compile(optimizer=optimizer, loss=[loss, loss], metrics=[accuracy])
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

model.summary()
# Out:
# DEBUG:filelock:Attempting to acquire lock 139615917038608 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 139615917038608 acquired on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 139615917038608 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 139615917038608 released on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_multiply (Dense)    (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_multiply (Dense)      (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_multiply[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_multiply[0][0]
# __________________________________________________________________________________________________
# flatten_start_multiply (Flatten (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_multiply (Flatten)  (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 512)          0           flatten_start_multiply[0][0]
#                                                                  flatten_int_multiply[0][0]
# __________________________________________________________________________________________________
# start_pred_multiply (Activation (None, 512)          0           flatten_start_multiply[0][0]
# __________________________________________________________________________________________________
# end_pred_multiply (Activation)  (None, 512)          0           multiply[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_multiply (Dense)    (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# ind_logit_multiply (Dense)      (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 512, 1)       0           start_logit_multiply[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 512, 1)       0           ind_logit_multiply[0][0]
# __________________________________________________________________________________________________
# flatten_start_multiply (Flatten (None, 512)          0           dropout_37[0][0]
# __________________________________________________________________________________________________
# flatten_int_multiply (Flatten)  (None, 512)          0           dropout_38[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 512)          0           flatten_start_multiply[0][0]
#                                                                  flatten_int_multiply[0][0]
# __________________________________________________________________________________________________
# start_pred_multiply (Activation (None, 512)          0           flatten_start_multiply[0][0]
# __________________________________________________________________________________________________
# end_pred_multiply (Activation)  (None, 512)          0           multiply[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=25,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/25
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 9.9591 - start_pred_multiply_loss: 4.5115 - end_pred_multiply_loss: 5.4476 - start_pred_multiply_accuracy: 0.2267 - end_pred_multiply_accuracy: 0.1328
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 423s 661ms/step - loss: 9.9591 - start_pred_multiply_loss: 4.5115 - end_pred_multiply_loss: 5.4476 - start_pred_multiply_accuracy: 0.2267 - end_pred_multiply_accuracy: 0.1328 - val_loss: 5.8835 - val_start_pred_multiply_loss: 2.4560 - val_end_pred_multiply_loss: 3.4276 - val_start_pred_multiply_accuracy: 0.5450 - val_end_pred_multiply_accuracy: 0.5643
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 2/25
# 507/507 [==============================] - 256s 506ms/step - loss: 8.8626 - start_pred_multiply_loss: 3.8274 - end_pred_multiply_loss: 5.0352 - start_pred_multiply_accuracy: 0.3479 - end_pred_multiply_accuracy: 0.1957 - val_loss: 4.8708 - val_start_pred_multiply_loss: 2.0119 - val_end_pred_multiply_loss: 2.8590 - val_start_pred_multiply_accuracy: 0.6043 - val_end_pred_multiply_accuracy: 0.6288
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 3/25
# 507/507 [==============================] - 257s 507ms/step - loss: 8.6114 - start_pred_multiply_loss: 3.6585 - end_pred_multiply_loss: 4.9529 - start_pred_multiply_accuracy: 0.3724 - end_pred_multiply_accuracy: 0.2049 - val_loss: 4.5076 - val_start_pred_multiply_loss: 1.8144 - val_end_pred_multiply_loss: 2.6932 - val_start_pred_multiply_accuracy: 0.6276 - val_end_pred_multiply_accuracy: 0.6577
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 4/25
# 507/507 [==============================] - 257s 506ms/step - loss: 8.4860 - start_pred_multiply_loss: 3.5842 - end_pred_multiply_loss: 4.9018 - start_pred_multiply_accuracy: 0.3847 - end_pred_multiply_accuracy: 0.2116 - val_loss: 4.2359 - val_start_pred_multiply_loss: 1.7190 - val_end_pred_multiply_loss: 2.5169 - val_start_pred_multiply_accuracy: 0.6405 - val_end_pred_multiply_accuracy: 0.6719
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 5/25
# 507/507 [==============================] - 257s 507ms/step - loss: 8.4031 - start_pred_multiply_loss: 3.5296 - end_pred_multiply_loss: 4.8734 - start_pred_multiply_accuracy: 0.3939 - end_pred_multiply_accuracy: 0.2140 - val_loss: 4.0970 - val_start_pred_multiply_loss: 1.6507 - val_end_pred_multiply_loss: 2.4463 - val_start_pred_multiply_accuracy: 0.6457 - val_end_pred_multiply_accuracy: 0.6788
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 6/25
# 507/507 [==============================] - 257s 506ms/step - loss: 8.2886 - start_pred_multiply_loss: 3.4651 - end_pred_multiply_loss: 4.8235 - start_pred_multiply_accuracy: 0.4035 - end_pred_multiply_accuracy: 0.2206 - val_loss: 3.7982 - val_start_pred_multiply_loss: 1.5752 - val_end_pred_multiply_loss: 2.2230 - val_start_pred_multiply_accuracy: 0.6534 - val_end_pred_multiply_accuracy: 0.6857
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 7/25
# 507/507 [==============================] - 257s 507ms/step - loss: 8.2460 - start_pred_multiply_loss: 3.4284 - end_pred_multiply_loss: 4.8177 - start_pred_multiply_accuracy: 0.4095 - end_pred_multiply_accuracy: 0.2218 - val_loss: 3.6357 - val_start_pred_multiply_loss: 1.4929 - val_end_pred_multiply_loss: 2.1428 - val_start_pred_multiply_accuracy: 0.6551 - val_end_pred_multiply_accuracy: 0.6882
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 8/25
# 507/507 [==============================] - 257s 506ms/step - loss: 8.1618 - start_pred_multiply_loss: 3.3662 - end_pred_multiply_loss: 4.7955 - start_pred_multiply_accuracy: 0.4189 - end_pred_multiply_accuracy: 0.2235 - val_loss: 3.6506 - val_start_pred_multiply_loss: 1.4980 - val_end_pred_multiply_loss: 2.1526 - val_start_pred_multiply_accuracy: 0.6588 - val_end_pred_multiply_accuracy: 0.6928
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 9/25
# 507/507 [==============================] - 257s 506ms/step - loss: 8.1356 - start_pred_multiply_loss: 3.3496 - end_pred_multiply_loss: 4.7859 - start_pred_multiply_accuracy: 0.4232 - end_pred_multiply_accuracy: 0.2238 - val_loss: 3.6554 - val_start_pred_multiply_loss: 1.4847 - val_end_pred_multiply_loss: 2.1708 - val_start_pred_multiply_accuracy: 0.6630 - val_end_pred_multiply_accuracy: 0.6949
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 10/25
# 507/507 [==============================] - 257s 506ms/step - loss: 8.0524 - start_pred_multiply_loss: 3.3054 - end_pred_multiply_loss: 4.7470 - start_pred_multiply_accuracy: 0.4295 - end_pred_multiply_accuracy: 0.2297 - val_loss: 3.7408 - val_start_pred_multiply_loss: 1.4866 - val_end_pred_multiply_loss: 2.2541 - val_start_pred_multiply_accuracy: 0.6570 - val_end_pred_multiply_accuracy: 0.6936
#
# Epoch 00010: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 11/25
# 507/507 [==============================] - 257s 506ms/step - loss: 8.0300 - start_pred_multiply_loss: 3.2902 - end_pred_multiply_loss: 4.7397 - start_pred_multiply_accuracy: 0.4314 - end_pred_multiply_accuracy: 0.2301 - val_loss: 3.4252 - val_start_pred_multiply_loss: 1.3872 - val_end_pred_multiply_loss: 2.0380 - val_start_pred_multiply_accuracy: 0.6622 - val_end_pred_multiply_accuracy: 0.6959
#
# Epoch 00011: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 12/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.9395 - start_pred_multiply_loss: 3.2340 - end_pred_multiply_loss: 4.7055 - start_pred_multiply_accuracy: 0.4412 - end_pred_multiply_accuracy: 0.2341 - val_loss: 3.1378 - val_start_pred_multiply_loss: 1.3651 - val_end_pred_multiply_loss: 1.7727 - val_start_pred_multiply_accuracy: 0.6621 - val_end_pred_multiply_accuracy: 0.6959
#
# Epoch 00012: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 13/25
# 507/507 [==============================] - 257s 507ms/step - loss: 7.9516 - start_pred_multiply_loss: 3.2158 - end_pred_multiply_loss: 4.7358 - start_pred_multiply_accuracy: 0.4438 - end_pred_multiply_accuracy: 0.2290 - val_loss: 3.4109 - val_start_pred_multiply_loss: 1.4285 - val_end_pred_multiply_loss: 1.9825 - val_start_pred_multiply_accuracy: 0.6592 - val_end_pred_multiply_accuracy: 0.6958
#
# Epoch 00013: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 14/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.8759 - start_pred_multiply_loss: 3.1824 - end_pred_multiply_loss: 4.6936 - start_pred_multiply_accuracy: 0.4495 - end_pred_multiply_accuracy: 0.2350 - val_loss: 3.3402 - val_start_pred_multiply_loss: 1.4023 - val_end_pred_multiply_loss: 1.9379 - val_start_pred_multiply_accuracy: 0.6577 - val_end_pred_multiply_accuracy: 0.6944
#
# Epoch 00014: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 15/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.8703 - start_pred_multiply_loss: 3.1692 - end_pred_multiply_loss: 4.7011 - start_pred_multiply_accuracy: 0.4514 - end_pred_multiply_accuracy: 0.2328 - val_loss: 3.1004 - val_start_pred_multiply_loss: 1.3853 - val_end_pred_multiply_loss: 1.7151 - val_start_pred_multiply_accuracy: 0.6626 - val_end_pred_multiply_accuracy: 0.6953
#
# Epoch 00015: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 16/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.8188 - start_pred_multiply_loss: 3.1399 - end_pred_multiply_loss: 4.6790 - start_pred_multiply_accuracy: 0.4564 - end_pred_multiply_accuracy: 0.2362 - val_loss: 3.2928 - val_start_pred_multiply_loss: 1.4044 - val_end_pred_multiply_loss: 1.8884 - val_start_pred_multiply_accuracy: 0.6603 - val_end_pred_multiply_accuracy: 0.6956
#
# Epoch 00016: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 17/25
# 507/507 [==============================] - 257s 507ms/step - loss: 7.7902 - start_pred_multiply_loss: 3.1152 - end_pred_multiply_loss: 4.6750 - start_pred_multiply_accuracy: 0.4605 - end_pred_multiply_accuracy: 0.2366 - val_loss: 2.9677 - val_start_pred_multiply_loss: 1.3829 - val_end_pred_multiply_loss: 1.5848 - val_start_pred_multiply_accuracy: 0.6559 - val_end_pred_multiply_accuracy: 0.6944
#
# Epoch 00017: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 18/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.7756 - start_pred_multiply_loss: 3.0981 - end_pred_multiply_loss: 4.6775 - start_pred_multiply_accuracy: 0.4622 - end_pred_multiply_accuracy: 0.2349 - val_loss: 3.2348 - val_start_pred_multiply_loss: 1.4009 - val_end_pred_multiply_loss: 1.8340 - val_start_pred_multiply_accuracy: 0.6581 - val_end_pred_multiply_accuracy: 0.6960
#
# Epoch 00018: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 19/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.7405 - start_pred_multiply_loss: 3.0739 - end_pred_multiply_loss: 4.6666 - start_pred_multiply_accuracy: 0.4661 - end_pred_multiply_accuracy: 0.2364 - val_loss: 3.1114 - val_start_pred_multiply_loss: 1.4069 - val_end_pred_multiply_loss: 1.7045 - val_start_pred_multiply_accuracy: 0.6549 - val_end_pred_multiply_accuracy: 0.6953
#
# Epoch 00019: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 20/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.6979 - start_pred_multiply_loss: 3.0477 - end_pred_multiply_loss: 4.6503 - start_pred_multiply_accuracy: 0.4696 - end_pred_multiply_accuracy: 0.2390 - val_loss: 3.1046 - val_start_pred_multiply_loss: 1.4293 - val_end_pred_multiply_loss: 1.6752 - val_start_pred_multiply_accuracy: 0.6522 - val_end_pred_multiply_accuracy: 0.6946
#
# Epoch 00020: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 21/25
# 507/507 [==============================] - 257s 507ms/step - loss: 7.6977 - start_pred_multiply_loss: 3.0367 - end_pred_multiply_loss: 4.6610 - start_pred_multiply_accuracy: 0.4717 - end_pred_multiply_accuracy: 0.2362 - val_loss: 3.0111 - val_start_pred_multiply_loss: 1.4599 - val_end_pred_multiply_loss: 1.5512 - val_start_pred_multiply_accuracy: 0.6503 - val_end_pred_multiply_accuracy: 0.6914
#
# Epoch 00021: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 22/25
# 507/507 [==============================] - 258s 509ms/step - loss: 7.6435 - start_pred_multiply_loss: 3.0039 - end_pred_multiply_loss: 4.6396 - start_pred_multiply_accuracy: 0.4762 - end_pred_multiply_accuracy: 0.2392 - val_loss: 3.2292 - val_start_pred_multiply_loss: 1.4340 - val_end_pred_multiply_loss: 1.7953 - val_start_pred_multiply_accuracy: 0.6509 - val_end_pred_multiply_accuracy: 0.6917
#
# Epoch 00022: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 23/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.6182 - start_pred_multiply_loss: 2.9908 - end_pred_multiply_loss: 4.6274 - start_pred_multiply_accuracy: 0.4779 - end_pred_multiply_accuracy: 0.2407 - val_loss: 3.0118 - val_start_pred_multiply_loss: 1.4942 - val_end_pred_multiply_loss: 1.5176 - val_start_pred_multiply_accuracy: 0.6492 - val_end_pred_multiply_accuracy: 0.6899
#
# Epoch 00023: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 24/25
# 507/507 [==============================] - 257s 507ms/step - loss: 7.6086 - start_pred_multiply_loss: 2.9812 - end_pred_multiply_loss: 4.6274 - start_pred_multiply_accuracy: 0.4797 - end_pred_multiply_accuracy: 0.2401 - val_loss: 3.0596 - val_start_pred_multiply_loss: 1.4776 - val_end_pred_multiply_loss: 1.5820 - val_start_pred_multiply_accuracy: 0.6501 - val_end_pred_multiply_accuracy: 0.6921
#
# Epoch 00024: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5
# Epoch 25/25
# 507/507 [==============================] - 257s 506ms/step - loss: 7.5909 - start_pred_multiply_loss: 2.9635 - end_pred_multiply_loss: 4.6274 - start_pred_multiply_accuracy: 0.4820 - end_pred_multiply_accuracy: 0.2399 - val_loss: 2.9442 - val_start_pred_multiply_loss: 1.5267 - val_end_pred_multiply_loss: 1.4175 - val_start_pred_multiply_accuracy: 0.6513 - val_end_pred_multiply_accuracy: 0.6932
#
# Epoch 00025: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_multiply.hdf5

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'start_pred_multiply_loss', 'end_pred_multiply_loss', 'start_pred_multiply_accuracy', 'end_pred_multiply_accuracy', 'val_loss', 'val_start_pred_multiply_loss', 'val_end_pred_multiply_loss', 'val_start_pred_multiply_accuracy', 'val_end_pred_multiply_accuracy'])

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_multiply_accuracy"])
plt.plot(history.history["end_pred_multiply_accuracy"])
plt.plot(history.history["val_start_pred_multiply_accuracy"])
plt.plot(history.history["val_end_pred_multiply_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['start_pred_accuracy', 'end_pred_accuracy', "val_start_pred_accuracy", "val_end_pred_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history['start_pred_multiply_loss'])
plt.plot(history.history['end_pred_multiply_loss'])
plt.plot(history.history['val_start_pred_multiply_loss'])
plt.plot(history.history['val_end_pred_multiply_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['start_pred_loss', 'end_pred_loss', "val_start_pred_loss", "val_end_pred_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # Vanilla

# %%
layer_option = "vanilla"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'
ES_start = EarlyStopping(monitor='val_start_pred_vanilla_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)
ES_end = EarlyStopping(monitor='val_end_pred_vanilla_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)


cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
strategy = tf.distribute.experimental.TPUStrategy(tpu)


# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_vanilla(model_name, inputs = inputs)

model.summary()

model.compile(optimizer=optimizer, loss=[loss, loss], metrics=[accuracy])
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

model.summary()
# Out:
# Running on TPU  ['10.114.208.34:8470']
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# DEBUG:filelock:Attempting to acquire lock 140456846907216 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140456846907216 acquired on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140456846907216 on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# DEBUG:filelock:Lock 140456846907216 released on /root/.cache/huggingface/transformers/775efbdc2152093295bc5824dee96da82a5f3c1f218dfface1b8cef3094bdf8f.c719a806caef7d36ec0185f14b3b5fa727d919f924abe35622b4b7147bfbb8c7.h5.lock
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_vanilla (Dense)     (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# end_logits_vanilla (Dense)      (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# flatten_start_vanilla (Flatten) (None, 512)          0           start_logit_vanilla[0][0]
# __________________________________________________________________________________________________
# flatten_end_vanilla (Flatten)   (None, 512)          0           end_logits_vanilla[0][0]
# __________________________________________________________________________________________________
# start_pred_vanilla (Activation) (None, 512)          0           flatten_start_vanilla[0][0]
# __________________________________________________________________________________________________
# end_pred_vanilla (Activation)   (None, 512)          0           flatten_end_vanilla[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# start_logit_vanilla (Dense)     (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# end_logits_vanilla (Dense)      (None, 512, 1)       768         tf_bert_model[0][0]
# __________________________________________________________________________________________________
# flatten_start_vanilla (Flatten) (None, 512)          0           start_logit_vanilla[0][0]
# __________________________________________________________________________________________________
# flatten_end_vanilla (Flatten)   (None, 512)          0           end_logits_vanilla[0][0]
# __________________________________________________________________________________________________
# start_pred_vanilla (Activation) (None, 512)          0           flatten_start_vanilla[0][0]
# __________________________________________________________________________________________________
# end_pred_vanilla (Activation)   (None, 512)          0           flatten_end_vanilla[0][0]
# ==================================================================================================
# Total params: 109,483,776
# Trainable params: 109,483,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=25,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/25
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 4.1879 - start_pred_vanilla_loss: 2.1392 - end_pred_vanilla_loss: 2.0487 - start_pred_vanilla_accuracy: 0.4552 - end_pred_vanilla_accuracy: 0.4870
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 417s 660ms/step - loss: 4.1879 - start_pred_vanilla_loss: 2.1392 - end_pred_vanilla_loss: 2.0487 - start_pred_vanilla_accuracy: 0.4552 - end_pred_vanilla_accuracy: 0.4870 - val_loss: 2.8209 - val_start_pred_vanilla_loss: 1.4542 - val_end_pred_vanilla_loss: 1.3667 - val_start_pred_vanilla_accuracy: 0.5938 - val_end_pred_vanilla_accuracy: 0.6332
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 2/25
# 507/507 [==============================] - 256s 506ms/step - loss: 2.3901 - start_pred_vanilla_loss: 1.2388 - end_pred_vanilla_loss: 1.1513 - start_pred_vanilla_accuracy: 0.6400 - end_pred_vanilla_accuracy: 0.6763 - val_loss: 2.4964 - val_start_pred_vanilla_loss: 1.3046 - val_end_pred_vanilla_loss: 1.1918 - val_start_pred_vanilla_accuracy: 0.6302 - val_end_pred_vanilla_accuracy: 0.6703
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 3/25
# 507/507 [==============================] - 256s 506ms/step - loss: 2.0152 - start_pred_vanilla_loss: 1.0537 - end_pred_vanilla_loss: 0.9615 - start_pred_vanilla_accuracy: 0.6813 - end_pred_vanilla_accuracy: 0.7222 - val_loss: 2.4159 - val_start_pred_vanilla_loss: 1.2706 - val_end_pred_vanilla_loss: 1.1454 - val_start_pred_vanilla_accuracy: 0.6435 - val_end_pred_vanilla_accuracy: 0.6880
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 4/25
# 507/507 [==============================] - 256s 506ms/step - loss: 1.7680 - start_pred_vanilla_loss: 0.9300 - end_pred_vanilla_loss: 0.8381 - start_pred_vanilla_accuracy: 0.7152 - end_pred_vanilla_accuracy: 0.7526 - val_loss: 2.3162 - val_start_pred_vanilla_loss: 1.2246 - val_end_pred_vanilla_loss: 1.0916 - val_start_pred_vanilla_accuracy: 0.6481 - val_end_pred_vanilla_accuracy: 0.6940
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 5/25
# 507/507 [==============================] - 257s 507ms/step - loss: 1.5601 - start_pred_vanilla_loss: 0.8214 - end_pred_vanilla_loss: 0.7388 - start_pred_vanilla_accuracy: 0.7411 - end_pred_vanilla_accuracy: 0.7778 - val_loss: 2.3490 - val_start_pred_vanilla_loss: 1.2338 - val_end_pred_vanilla_loss: 1.1152 - val_start_pred_vanilla_accuracy: 0.6534 - val_end_pred_vanilla_accuracy: 0.7000
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 6/25
# 507/507 [==============================] - 257s 506ms/step - loss: 1.3872 - start_pred_vanilla_loss: 0.7347 - end_pred_vanilla_loss: 0.6525 - start_pred_vanilla_accuracy: 0.7628 - end_pred_vanilla_accuracy: 0.7994 - val_loss: 2.4927 - val_start_pred_vanilla_loss: 1.3121 - val_end_pred_vanilla_loss: 1.1806 - val_start_pred_vanilla_accuracy: 0.6563 - val_end_pred_vanilla_accuracy: 0.6998
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 7/25
# 507/507 [==============================] - 257s 506ms/step - loss: 1.2386 - start_pred_vanilla_loss: 0.6585 - end_pred_vanilla_loss: 0.5800 - start_pred_vanilla_accuracy: 0.7830 - end_pred_vanilla_accuracy: 0.8177 - val_loss: 2.4426 - val_start_pred_vanilla_loss: 1.2889 - val_end_pred_vanilla_loss: 1.1536 - val_start_pred_vanilla_accuracy: 0.6555 - val_end_pred_vanilla_accuracy: 0.6989
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 8/25
# 507/507 [==============================] - 257s 506ms/step - loss: 1.1039 - start_pred_vanilla_loss: 0.5867 - end_pred_vanilla_loss: 0.5171 - start_pred_vanilla_accuracy: 0.8029 - end_pred_vanilla_accuracy: 0.8339 - val_loss: 2.5669 - val_start_pred_vanilla_loss: 1.3543 - val_end_pred_vanilla_loss: 1.2126 - val_start_pred_vanilla_accuracy: 0.6568 - val_end_pred_vanilla_accuracy: 0.6993
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 9/25
# 507/507 [==============================] - 257s 506ms/step - loss: 0.9826 - start_pred_vanilla_loss: 0.5239 - end_pred_vanilla_loss: 0.4587 - start_pred_vanilla_accuracy: 0.8210 - end_pred_vanilla_accuracy: 0.8521 - val_loss: 2.6307 - val_start_pred_vanilla_loss: 1.3875 - val_end_pred_vanilla_loss: 1.2433 - val_start_pred_vanilla_accuracy: 0.6529 - val_end_pred_vanilla_accuracy: 0.6965
# Restoring model weights from the end of the best epoch.
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_vanilla.hdf5
# Epoch 00009: early stopping

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_vanilla_accuracy"])
plt.plot(history.history["end_pred_vanilla_accuracy"])
plt.plot(history.history["val_start_pred_vanilla_accuracy"])
plt.plot(history.history["val_end_pred_vanilla_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['start_pred_accuracy', 'end_pred_accuracy', "val_start_pred_accuracy", "val_end_pred_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history['start_pred_vanilla_loss'])
plt.plot(history.history['end_pred_vanilla_loss'])
plt.plot(history.history['val_start_pred_vanilla_loss'])
plt.plot(history.history['val_end_pred_vanilla_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['start_pred_loss', 'end_pred_loss', "val_start_pred_loss", "val_end_pred_loss"], loc='upper left')
plt.show()

# %% [markdown]
# # CNN

# %%
layer_option = "cnn"

# %%
chkpt = save_path + model_name + '_' + layer_option + '.hdf5'
ES_start = EarlyStopping(monitor='val_start_pred_cnn_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)
ES_end = EarlyStopping(monitor='val_end_pred_cnn_accuracy', patience=4,verbose=1, mode='auto', restore_best_weights = True)


cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, 
                        save_best_only=False, mode='auto', 
                        save_weights_only=True)

callbacks = [ES_end, ES_start, cp_cb]

# BERT e Bert tokenizer following model_name
# Create model
with strategy.scope():
    model = create_bert_CNN(model_name, inputs = inputs)

model.summary()

model.compile(optimizer=optimizer, loss=[loss, loss], metrics=[accuracy])
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

model.summary()
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 512, 768)     5899008     tf_bert_model[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 512, 768)     5899008     tf_bert_model[0][0]
# __________________________________________________________________________________________________
# start_logit_cnn (Dense)         (None, 512, 1)       768         conv1d[0][0]
# __________________________________________________________________________________________________
# end_logits_cnn (Dense)          (None, 512, 1)       768         conv1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_start_cnn (Flatten)     (None, 512)          0           start_logit_cnn[0][0]
# __________________________________________________________________________________________________
# flatten_end_cnn (Flatten)       (None, 512)          0           end_logits_cnn[0][0]
# __________________________________________________________________________________________________
# start_pred_cnn (Activation)     (None, 512)          0           flatten_start_cnn[0][0]
# __________________________________________________________________________________________________
# end_pred_cnn (Activation)       (None, 512)          0           flatten_end_cnn[0][0]
# ==================================================================================================
# Total params: 121,281,792
# Trainable params: 121,281,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 512)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# token_type_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109482240   input_ids[0][0]
#                                                                  attention_mask[0][0]
#                                                                  token_type_ids[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 512, 768)     5899008     tf_bert_model[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 512, 768)     5899008     tf_bert_model[0][0]
# __________________________________________________________________________________________________
# start_logit_cnn (Dense)         (None, 512, 1)       768         conv1d[0][0]
# __________________________________________________________________________________________________
# end_logits_cnn (Dense)          (None, 512, 1)       768         conv1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_start_cnn (Flatten)     (None, 512)          0           start_logit_cnn[0][0]
# __________________________________________________________________________________________________
# flatten_end_cnn (Flatten)       (None, 512)          0           end_logits_cnn[0][0]
# __________________________________________________________________________________________________
# start_pred_cnn (Activation)     (None, 512)          0           flatten_start_cnn[0][0]
# __________________________________________________________________________________________________
# end_pred_cnn (Activation)       (None, 512)          0           flatten_end_cnn[0][0]
# ==================================================================================================
# Total params: 121,281,792
# Trainable params: 121,281,792
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, dpi=55, show_shapes=True)

# %%
history = model.fit(
            x_train,
            y_train,
            epochs=25,  # For demonstration, 3 epochs are recommended
            verbose=1,
            batch_size=128,
            validation_data=(x_val,y_val),
            callbacks = callbacks)
# Out:
# Epoch 1/25
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - ETA: 0s - loss: 3.8321 - start_pred_cnn_loss: 1.9531 - end_pred_cnn_loss: 1.8790 - start_pred_cnn_accuracy: 0.4911 - end_pred_cnn_accuracy: 0.5160
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Identity:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_1:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_2:0' shape=(None, 512) dtype=int64>, <tf.Tensor 'cond_8/Identity_3:0' shape=(None,) dtype=float32>, <tf.Tensor 'cond_8/Identity_4:0' shape=(None,) dtype=float32>]
# 507/507 [==============================] - 459s 723ms/step - loss: 3.8321 - start_pred_cnn_loss: 1.9531 - end_pred_cnn_loss: 1.8790 - start_pred_cnn_accuracy: 0.4911 - end_pred_cnn_accuracy: 0.5160 - val_loss: 2.7285 - val_start_pred_cnn_loss: 1.4020 - val_end_pred_cnn_loss: 1.3265 - val_start_pred_cnn_accuracy: 0.6010 - val_end_pred_cnn_accuracy: 0.6403
#
# Epoch 00001: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 2/25
# 507/507 [==============================] - 275s 542ms/step - loss: 2.2935 - start_pred_cnn_loss: 1.1812 - end_pred_cnn_loss: 1.1123 - start_pred_cnn_accuracy: 0.6526 - end_pred_cnn_accuracy: 0.6877 - val_loss: 2.4551 - val_start_pred_cnn_loss: 1.2777 - val_end_pred_cnn_loss: 1.1774 - val_start_pred_cnn_accuracy: 0.6344 - val_end_pred_cnn_accuracy: 0.6754
#
# Epoch 00002: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 3/25
# 507/507 [==============================] - 275s 542ms/step - loss: 1.9337 - start_pred_cnn_loss: 1.0052 - end_pred_cnn_loss: 0.9285 - start_pred_cnn_accuracy: 0.6976 - end_pred_cnn_accuracy: 0.7332 - val_loss: 2.3746 - val_start_pred_cnn_loss: 1.2377 - val_end_pred_cnn_loss: 1.1369 - val_start_pred_cnn_accuracy: 0.6472 - val_end_pred_cnn_accuracy: 0.6859
#
# Epoch 00003: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 4/25
# 507/507 [==============================] - 275s 543ms/step - loss: 1.6680 - start_pred_cnn_loss: 0.8717 - end_pred_cnn_loss: 0.7963 - start_pred_cnn_accuracy: 0.7323 - end_pred_cnn_accuracy: 0.7670 - val_loss: 2.3484 - val_start_pred_cnn_loss: 1.2275 - val_end_pred_cnn_loss: 1.1209 - val_start_pred_cnn_accuracy: 0.6550 - val_end_pred_cnn_accuracy: 0.6929
#
# Epoch 00004: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 5/25
# 507/507 [==============================] - 275s 543ms/step - loss: 1.4631 - start_pred_cnn_loss: 0.7702 - end_pred_cnn_loss: 0.6929 - start_pred_cnn_accuracy: 0.7579 - end_pred_cnn_accuracy: 0.7920 - val_loss: 2.3886 - val_start_pred_cnn_loss: 1.2494 - val_end_pred_cnn_loss: 1.1392 - val_start_pred_cnn_accuracy: 0.6574 - val_end_pred_cnn_accuracy: 0.6957
#
# Epoch 00005: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 6/25
# 507/507 [==============================] - 275s 543ms/step - loss: 1.2782 - start_pred_cnn_loss: 0.6760 - end_pred_cnn_loss: 0.6021 - start_pred_cnn_accuracy: 0.7804 - end_pred_cnn_accuracy: 0.8171 - val_loss: 2.4184 - val_start_pred_cnn_loss: 1.2665 - val_end_pred_cnn_loss: 1.1519 - val_start_pred_cnn_accuracy: 0.6566 - val_end_pred_cnn_accuracy: 0.6985
#
# Epoch 00006: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 7/25
# 507/507 [==============================] - 275s 542ms/step - loss: 1.1196 - start_pred_cnn_loss: 0.5957 - end_pred_cnn_loss: 0.5240 - start_pred_cnn_accuracy: 0.8027 - end_pred_cnn_accuracy: 0.8366 - val_loss: 2.5752 - val_start_pred_cnn_loss: 1.3471 - val_end_pred_cnn_loss: 1.2281 - val_start_pred_cnn_accuracy: 0.6564 - val_end_pred_cnn_accuracy: 0.6960
#
# Epoch 00007: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 8/25
# 507/507 [==============================] - 275s 543ms/step - loss: 0.9820 - start_pred_cnn_loss: 0.5247 - end_pred_cnn_loss: 0.4573 - start_pred_cnn_accuracy: 0.8249 - end_pred_cnn_accuracy: 0.8550 - val_loss: 2.7295 - val_start_pred_cnn_loss: 1.4272 - val_end_pred_cnn_loss: 1.3023 - val_start_pred_cnn_accuracy: 0.6565 - val_end_pred_cnn_accuracy: 0.6957
#
# Epoch 00008: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 9/25
# 507/507 [==============================] - 294s 580ms/step - loss: 0.8597 - start_pred_cnn_loss: 0.4629 - end_pred_cnn_loss: 0.3968 - start_pred_cnn_accuracy: 0.8422 - end_pred_cnn_accuracy: 0.8720 - val_loss: 2.8779 - val_start_pred_cnn_loss: 1.4996 - val_end_pred_cnn_loss: 1.3783 - val_start_pred_cnn_accuracy: 0.6477 - val_end_pred_cnn_accuracy: 0.6946
# Restoring model weights from the end of the best epoch.
#
# Epoch 00009: saving model to /content/drive/MyDrive/NLP/proj finale/saved_models/bert-base-uncased_cnn.hdf5
# Epoch 00009: early stopping

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt

plt.figure(figsize=(15,8))
plt.plot(history.history["start_pred_cnn_accuracy"])
plt.plot(history.history["end_pred_cnn_accuracy"])
plt.plot(history.history["val_start_pred_cnn_accuracy"])
plt.plot(history.history["val_end_pred_cnn_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['start_pred_accuracy', 'end_pred_accuracy', "val_start_pred_accuracy", "val_end_pred_accuracy"], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,8))

plt.plot(history.history['start_pred_cnn_loss'])
plt.plot(history.history['end_pred_cnn_loss'])
plt.plot(history.history['val_start_pred_cnn_loss'])
plt.plot(history.history['val_end_pred_cnn_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['start_pred_loss', 'end_pred_loss', "val_start_pred_loss", "val_end_pred_loss"], loc='upper left')
plt.show()
